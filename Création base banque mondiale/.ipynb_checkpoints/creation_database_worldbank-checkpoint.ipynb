# %% [markdown]
# Dans ce notebook, on indique la démarche suivie pour créer une base de donnée prête à être analysée à partir des indicateurs issus de la banque mondiale (https://data.worldbank.org/indicator/). On peut reprendre cette démarche pour rajouter ou enlever d'autres indicateurs, et on peut à la fin choisir de ne conserver que certains pays en en mettant la liste.
#
# La base créée dans ce code comporte 5 indicateurs (PIB, PIB_HAB, FBCF en dollars, Tx de chômage et Exportations en dollars). On dispose de ces données complètes entre 2000 et 2018 pour 145 pays

# %% [markdown]
# # Code

# %% [markdown]
# On commence par importer les modules nécessaires, et on crée quelques foncions qui vont nous aider à manipuler les dataframe en jonglant entre les codes et les noms des pays

# %%
import pandas as pd
import re
import numpy as np

def refresh_dico(Name,Code,df):
    dico = {}
    for i in df[[Name,Code]].dropna().drop_duplicates().iterrows() :
        dico[i[1][Name]] = i[1][Code]
    return (dico)

def rech_ligne_pays (y,df) :
    expression = re.compile(dic_pays[y]+".*?;")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)+';'))))

def rech_ligne_indic (y,df):
    expression = re.compile(".{,4}"+y+";")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)+';'))))

# %% [markdown]
# On importe ensuite les bases au format csv, que l'on est allé chercher sur le site de la banque mondiale qui est en open data (https://data.worldbank.org/indicator/).
#
# Attention, pour ouvrir proprement ces données, il faut d'abord ouvrir les csv dans le bloc notes (ou n'importe quel autre logiciel capable de les ouvrir), et supprimer les deux premières lignes du document qui correspondent plus ou moins au titre du document, mais qui font bugger la fonction pd.read_csv.

# %%
#Importation des bases csv, et crétaion de la base aggrégée
gdp = pd.read_csv('pib.csv')
gdp['Simple Indicator'] = 'gdp'

for i in range(1960, 2021):
    gdp[str(i)] = gdp[str(i)] / 1000000
gdp['Indicator Name'] = 'GDP (current million US$)'

gdp_hab = pd.read_csv('pib_hab.csv')
gdp_hab['Simple Indicator'] = 'gdb_hab'

fbcf = pd.read_csv('FBCF.csv')
fbcf['Simple Indicator'] = 'FBCF'

exports_rate = pd.read_csv('exports_rate.csv')
exports_rate['Simple Indicator'] = 'exports_rate'

unemployment_rate = pd.read_csv('unemployment_rate.csv')
unemployment_rate['Simple Indicator'] = 'unemployment rate'

pop = pd.read_csv('pop.csv')
pop['Simple Indicator'] = 'pop'

labor_force = pd.read_csv('labor force.csv')
labor_force ['Simple Indicator'] = 'labor_force'

# %%
#création de la base aggrégée
df_list = [gdp, gdp_hab, fbcf, unemployment_rate, exports_rate, pop, labor_force]

for df in df_list :
    df['Pays_indic'] = df['Country Code'].str[:3] + '_' + df['Indicator Name'].str[:99]
df1 = pd.concat(df_list)
df1 = df1.sort_values('Pays_indic').set_index('Pays_indic')
df1.head(3)
# Out:
#                                              Country Name Country Code  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        Aruba          ABW
# ABW_GDP (current million US$)                       Aruba          ABW
# ABW_GDP per capita (current US$)                    Aruba          ABW
#
#                                                                         Indicator Name  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)  Exports of goods and services (% of GDP)
# ABW_GDP (current million US$)                                GDP (current million US$)
# ABW_GDP per capita (current US$)                          GDP per capita (current US$)
#
#                                               Indicator Code  1960  1961  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)  NE.EXP.GNFS.ZS   NaN   NaN
# ABW_GDP (current million US$)                 NY.GDP.MKTP.CD   NaN   NaN
# ABW_GDP per capita (current US$)              NY.GDP.PCAP.CD   NaN   NaN
#
#                                               1962  1963  1964  1965  ...  \
# Pays_indic                                                            ...
# ABW_Exports of goods and services (% of GDP)   NaN   NaN   NaN   NaN  ...
# ABW_GDP (current million US$)                  NaN   NaN   NaN   NaN  ...
# ABW_GDP per capita (current US$)               NaN   NaN   NaN   NaN  ...
#
#                                                       2013          2014  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)     76.509512     77.555556
# ABW_GDP (current million US$)                  2701.675978   2765.363128
# ABW_GDP per capita (current US$)              26189.435509  26647.938101
#
#                                                       2015          2016  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)     73.517030     71.294029
# ABW_GDP (current million US$)                  2919.553073   2965.921788
# ABW_GDP per capita (current US$)              27980.880695  28281.350482
#
#                                                       2017  2018  2019  2020  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)     73.332115   NaN   NaN   NaN
# ABW_GDP (current million US$)                  3056.424581   NaN   NaN   NaN
# ABW_GDP per capita (current US$)              29007.693003   NaN   NaN   NaN
#
#                                               Unnamed: 65  Simple Indicator
# Pays_indic
# ABW_Exports of goods and services (% of GDP)          NaN      exports_rate
# ABW_GDP (current million US$)                         NaN               gdp
# ABW_GDP per capita (current US$)                      NaN           gdb_hab
#
# [3 rows x 67 columns]

# %% [markdown]
# On supprime d'abord les colonnes qui ne nous servent à rien : le nom de code de l'indicateur, les années que l'on ne conserve pas pour l'étude, et la dernière colonne qui est un bug lors de l'ouverture de ces données avec la fonction pd.read_csv
#
# On fait ensuite de même avec les lignes, en supprimant tous les aggrégats de pays qui ne sont pas proprement des pays

# %%
#SUPPRESSION DES LIGNES ET COLONNES INUTILES
dic_pays = refresh_dico('Country Name','Country Code',df1)


useless_data_list = ['Unnamed: 65', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', 
                   '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', 
                   '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
                   '1995', '1996', '1997', '1998', '1999', '2019', '2020']
df1 = df1.drop(useless_data_list, axis = 1)


suppr_liste = ['Arab World', 'Central Europe and the Baltics',
 'Caribbean small states', 'East Asia & Pacific (excluding high income)', 
  'Early-demographic dividend', 
 'East Asia & Pacific',
 'Europe & Central Asia (excluding high income)', 
 'Europe & Central Asia',  
 'European Union','Fragile and conflict affected situations',
 'High income',
 'Heavily indebted poor countries (HIPC)','IBRD only',
 'IDA & IBRD total',
 'IDA total',
 'IDA blend',
 'IDA only',
 'Latin America & Caribbean (excluding high income)',
 'Latin America & Caribbean',
 'Least developed countries: UN classification',
 'Low income',
 'Lower middle income',
 'Low & middle income',
 'Late-demographic dividend',
 'Middle East & North Africa',
 'Middle income',
 'Middle East & North Africa (excluding high income)',
 'North America',
 'OECD members',
 'Other small states',
 'Pre-demographic dividend',
 'Pacific island small states',
 'Post-demographic dividend',
 'South Asia',
 'Sub-Saharan Africa (excluding high income)',
 'Sub-Saharan Africa',
 'Small states',
 'East Asia & Pacific (IDA & IBRD countries)',
 'Europe & Central Asia (IDA & IBRD countries)',
 'Latin America & the Caribbean (IDA & IBRD countries)',
 'Middle East & North Africa (IDA & IBRD countries)',
 'South Asia (IDA & IBRD)',
 'Sub-Saharan Africa (IDA & IBRD countries)',
 'Upper middle income',
 'World',
 'Central African Republic',
 'West Bank and Gaza',
 'Hong Kong SAR, China',
 'Macao SAR, China']
for i in suppr_liste :
    df1 = df1.drop(labels = rech_ligne_pays(i,df1))

# %% [markdown]
# On supprime maintenant tous les pays pour lesquels il manque au moins un indicateur. On le fait en deux étapes :
#
# (1) On supprime toutes les lignes où il manque au moins une donnée à un moment donné.
# (2) On supprime toutes les lignes de tous les pays pour lesquels on a supprimé au moins une ligne

# %%
#Étape 1
df1 = df1.dropna(axis = 0)
df1.head(7)

#Étape 2 
dic_code = refresh_dico('Country Code','Country Name',df1)

for i in dic_pays.keys() :
    if len(rech_ligne_pays(i,df1)) < len(df_list) :
        df1 = df1.drop(rech_ligne_pays(i,df1))

dic_code = refresh_dico('Country Code','Country Name',df1)

#On affiche le nombre de pays restant dans la base
print(len(dic_code.keys()))
# Out:
# 145

# %% [markdown]
# On recrée maintenant la variable correpondant aux exportations par pays en dollars, à partir du PIB et des exportations en pourcentage du PIB.
#
# Après l'avoir fait, on peut supprimer l'ancienne variable qui exprime les exportations en pct du PIB en enlevant le # sur la ligne correspondante.
#
# On a utlisé la formule :
#
#     Exportation$ = (Exportations%PIB * PIB)/100

# %%
#CREATION DE LA VARIABLE EXPORTATION A PARTIR DE EXPORTATION RATE ET DU PIB

for i in dic_code.keys():
    df1.loc[i+ '_Exports of goods and services (current million US$)']= (df1.loc[i+'_Exports of goods and services (% of GDP)'][3:df1.shape[1]-1].astype(np.float64) * df1.loc[i+'_GDP (current million US$)'][3:df1.shape[1]-1].astype(np.float64)) / 100
    df1.loc[i+ '_Exports of goods and services (current million US$)',['Country Name','Country Code']]=df1.loc[i+'_Exports of goods and services (% of GDP)',['Country Name','Country Code']]
    df1.loc[i+ '_Exports of goods and services (current million US$)','Indicator Name']= 'Exports of goods and services (current million US$)'
    df1.loc[i+ '_Exports of goods and services (current million US$)','Simple Indicator'] = 'exports'
    #df1 = df1.drop(labels = i+'_Exports of goods and services (% of GDP)')
df1 = df1.sort_index()

# %% [markdown]
# On va maintenant créer les variables par habitant, et par population active

# %%
def gen_per_capita(variable):
    for i in dic_code.keys():
        df1.loc[i+variable+' per capita']= df1.loc[i+variable][3:df1.shape[1]-1].astype(np.float64) / df1.loc[i+'_Population, total'][3:df1.shape[1]-1].astype(np.float64)
        df1.loc[i+variable+' per capita',['Country Name','Country Code']]=df1.loc[i+variable,['Country Name','Country Code']]
        df1.loc[i+variable+' per capita','Indicator Name']= variable + ' per capita'
        df1.loc[i+variable+' per capita','Simple Indicator'] = df1.loc[i+variable, 'Simple Indicator'] + '_hab'
    return
gen_per_capita('_Exports of goods and services (current million US$)')

def gen_per_labor_unit(variable) :
    for i in dic_code.keys():
        df1.loc[i+variable+' per labor unit']= df1.loc[i+variable][3:df1.shape[1]-1].astype(np.float64) / df1.loc[i+'_Labor force, total'][3:df1.shape[1]-1].astype(np.float64)
        df1.loc[i+variable+' per labor unit',['Country Name','Country Code']]=df1.loc[i+variable,['Country Name','Country Code']]
        df1.loc[i+variable+' per labor unit','Indicator Name']= variable + ' per labor unit'
        df1.loc[i+variable+' per labor unit','Simple Indicator'] = df1.loc[i+variable, 'Simple Indicator'] + '_labor_unit'
    return
gen_per_labor_unit('_Exports of goods and services (current million US$)')
df1 = df1.sort_index()

# %%
df1.head(10)
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)             Angola          AGO
# AGO_Exports of goods and services (current mill...       Angola          AGO
# AGO_Exports of goods and services (current mill...       Angola          AGO
# AGO_Exports of goods and services (current mill...       Angola          AGO
# AGO_GDP (current million US$)                            Angola          AGO
# AGO_GDP per capita (current US$)                         Angola          AGO
# AGO_Gross capital formation (% of GDP)                   Angola          AGO
# AGO_Labor force, total                                   Angola          AGO
# AGO_Population, total                                    Angola          AGO
# AGO_Unemployment, total (% of total labor force...       Angola          AGO
#
#                                                                                        Indicator Name  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# AGO_Exports of goods and services (current mill...  Exports of goods and services (current million...
# AGO_Exports of goods and services (current mill...  _Exports of goods and services (current millio...
# AGO_Exports of goods and services (current mill...  _Exports of goods and services (current millio...
# AGO_GDP (current million US$)                                               GDP (current million US$)
# AGO_GDP per capita (current US$)                                         GDP per capita (current US$)
# AGO_Gross capital formation (% of GDP)                             Gross capital formation (% of GDP)
# AGO_Labor force, total                                                             Labor force, total
# AGO_Population, total                                                               Population, total
# AGO_Unemployment, total (% of total labor force...  Unemployment, total (% of total labor force) (...
#
#                                                             2000  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        8.968583e+01
# AGO_Exports of goods and services (current mill...  8.187953e+03
# AGO_Exports of goods and services (current mill...  4.994033e-04
# AGO_Exports of goods and services (current mill...  1.219836e-03
# AGO_GDP (current million US$)                       9.129595e+03
# AGO_GDP per capita (current US$)                    5.568363e+02
# AGO_Gross capital formation (% of GDP)              3.049322e+01
# AGO_Labor force, total                              6.712338e+06
# AGO_Population, total                               1.639547e+07
# AGO_Unemployment, total (% of total labor force...  3.837000e+00
#
#                                                             2001  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        7.538894e+01
# AGO_Exports of goods and services (current mill...  6.736804e+03
# AGO_Exports of goods and services (current mill...  3.975512e-04
# AGO_Exports of goods and services (current mill...  9.712125e-04
# AGO_GDP (current million US$)                       8.936064e+03
# AGO_GDP per capita (current US$)                    5.273335e+02
# AGO_Gross capital formation (% of GDP)              3.049322e+01
# AGO_Labor force, total                              6.936488e+06
# AGO_Population, total                               1.694575e+07
# AGO_Unemployment, total (% of total labor force...  3.835000e+00
#
#                                                             2002  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        5.708500e+01
# AGO_Exports of goods and services (current mill...  8.725781e+03
# AGO_Exports of goods and services (current mill...  4.980634e-04
# AGO_Exports of goods and services (current mill...  1.217387e-03
# AGO_GDP (current million US$)                       1.528559e+04
# AGO_GDP per capita (current US$)                    8.724945e+02
# AGO_Gross capital formation (% of GDP)              3.049317e+01
# AGO_Labor force, total                              7.167634e+06
# AGO_Population, total                               1.751942e+07
# AGO_Unemployment, total (% of total labor force...  3.871000e+00
#
#                                                             2003  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        5.432134e+01
# AGO_Exports of goods and services (current mill...  9.676100e+03
# AGO_Exports of goods and services (current mill...  5.339575e-04
# AGO_Exports of goods and services (current mill...  1.304164e-03
# AGO_GDP (current million US$)                       1.781271e+04
# AGO_GDP per capita (current US$)                    9.829609e+02
# AGO_Gross capital formation (% of GDP)              3.045111e+01
# AGO_Labor force, total                              7.419387e+06
# AGO_Population, total                               1.812148e+07
# AGO_Unemployment, total (% of total labor force...  3.875000e+00
#
#                                                             2004  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        5.838035e+01
# AGO_Exports of goods and services (current mill...  1.374977e+04
# AGO_Exports of goods and services (current mill...  7.330026e-04
# AGO_Exports of goods and services (current mill...  1.789817e-03
# AGO_GDP (current million US$)                       2.355205e+04
# AGO_GDP per capita (current US$)                    1.255564e+03
# AGO_Gross capital formation (% of GDP)              3.089367e+01
# AGO_Labor force, total                              7.682222e+06
# AGO_Population, total                               1.875814e+07
# AGO_Unemployment, total (% of total labor force...  3.842000e+00
#
#                                                             2005  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        6.552627e+01
# AGO_Exports of goods and services (current mill...  2.422566e+04
# AGO_Exports of goods and services (current mill...  1.246586e-03
# AGO_Exports of goods and services (current mill...  3.043671e-03
# AGO_GDP (current million US$)                       3.697092e+04
# AGO_GDP per capita (current US$)                    1.902422e+03
# AGO_Gross capital formation (% of GDP)              2.755658e+01
# AGO_Labor force, total                              7.959356e+06
# AGO_Population, total                               1.943360e+07
# AGO_Unemployment, total (% of total labor force...  3.800000e+00
#
#                                                             2006  ...  \
# Pays_indic                                                        ...
# AGO_Exports of goods and services (% of GDP)        6.346786e+01  ...
# AGO_Exports of goods and services (current mill...  3.324511e+04  ...
# AGO_Exports of goods and services (current mill...  1.649889e-03  ...
# AGO_Exports of goods and services (current mill...  4.032362e-03  ...
# AGO_GDP (current million US$)                       5.238101e+04  ...
# AGO_GDP per capita (current US$)                    2.599566e+03  ...
# AGO_Gross capital formation (% of GDP)              2.330077e+01  ...
# AGO_Labor force, total                              8.244573e+06  ...
# AGO_Population, total                               2.014990e+07  ...
# AGO_Unemployment, total (% of total labor force...  3.712000e+00  ...
#
#                                                             2010  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        6.154311e+01
# AGO_Exports of goods and services (current mill...  5.157282e+04
# AGO_Exports of goods and services (current mill...  2.208095e-03
# AGO_Exports of goods and services (current mill...  5.394397e-03
# AGO_GDP (current million US$)                       8.379950e+04
# AGO_GDP per capita (current US$)                    3.587884e+03
# AGO_Gross capital formation (% of GDP)              2.819731e+01
# AGO_Labor force, total                              9.560441e+06
# AGO_Population, total                               2.335625e+07
# AGO_Unemployment, total (% of total labor force...  9.430000e+00
#
#                                                             2011  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        6.066995e+01
# AGO_Exports of goods and services (current mill...  6.782275e+04
# AGO_Exports of goods and services (current mill...  2.800202e-03
# AGO_Exports of goods and services (current mill...  6.843792e-03
# AGO_GDP (current million US$)                       1.117897e+05
# AGO_GDP per capita (current US$)                    4.615468e+03
# AGO_Gross capital formation (% of GDP)              2.642435e+01
# AGO_Labor force, total                              9.910112e+06
# AGO_Population, total                               2.422066e+07
# AGO_Unemployment, total (% of total labor force...  7.362000e+00
#
#                                                             2012  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        5.594013e+01
# AGO_Exports of goods and services (current mill...  7.163293e+04
# AGO_Exports of goods and services (current mill...  2.853000e-03
# AGO_Exports of goods and services (current mill...  6.974856e-03
# AGO_GDP (current million US$)                       1.280529e+05
# AGO_GDP per capita (current US$)                    5.100096e+03
# AGO_Gross capital formation (% of GDP)              2.666758e+01
# AGO_Labor force, total                              1.027017e+07
# AGO_Population, total                               2.510793e+07
# AGO_Unemployment, total (% of total labor force...  7.379000e+00
#
#                                                             2013  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        5.074708e+01
# AGO_Exports of goods and services (current mill...  6.937627e+04
# AGO_Exports of goods and services (current mill...  2.666700e-03
# AGO_Exports of goods and services (current mill...  6.516270e-03
# AGO_GDP (current million US$)                       1.367099e+05
# AGO_GDP per capita (current US$)                    5.254882e+03
# AGO_Gross capital formation (% of GDP)              2.614297e+01
# AGO_Labor force, total                              1.064662e+07
# AGO_Population, total                               2.601578e+07
# AGO_Unemployment, total (% of total labor force...  7.400000e+00
#
#                                                             2014  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        4.469503e+01
# AGO_Exports of goods and services (current mill...  6.512611e+04
# AGO_Exports of goods and services (current mill...  2.417291e-03
# AGO_Exports of goods and services (current mill...  5.901985e-03
# AGO_GDP (current million US$)                       1.457122e+05
# AGO_GDP per capita (current US$)                    5.408410e+03
# AGO_Gross capital formation (% of GDP)              2.750046e+01
# AGO_Labor force, total                              1.103461e+07
# AGO_Population, total                               2.694178e+07
# AGO_Unemployment, total (% of total labor force...  7.331000e+00
#
#                                                             2015  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        2.975460e+01
# AGO_Exports of goods and services (current mill...  3.457295e+04
# AGO_Exports of goods and services (current mill...  1.239868e-03
# AGO_Exports of goods and services (current mill...  3.022660e-03
# AGO_GDP (current million US$)                       1.161936e+05
# AGO_GDP per capita (current US$)                    4.166980e+03
# AGO_Gross capital formation (% of GDP)              3.420249e+01
# AGO_Labor force, total                              1.143792e+07
# AGO_Population, total                               2.788438e+07
# AGO_Unemployment, total (% of total labor force...  7.282000e+00
#
#                                                             2016  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        2.812448e+01
# AGO_Exports of goods and services (current mill...  2.844056e+04
# AGO_Exports of goods and services (current mill...  9.860649e-04
# AGO_Exports of goods and services (current mill...  2.400369e-03
# AGO_GDP (current million US$)                       1.011239e+05
# AGO_GDP per capita (current US$)                    3.506073e+03
# AGO_Gross capital formation (% of GDP)              2.721471e+01
# AGO_Labor force, total                              1.184841e+07
# AGO_Population, total                               2.884248e+07
# AGO_Unemployment, total (% of total labor force...  7.223000e+00
#
#                                                             2017  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        2.900410e+01
# AGO_Exports of goods and services (current mill...  3.542092e+04
# AGO_Exports of goods and services (current mill...  1.187954e-03
# AGO_Exports of goods and services (current mill...  2.887063e-03
# AGO_GDP (current million US$)                       1.221238e+05
# AGO_GDP per capita (current US$)                    4.095813e+03
# AGO_Gross capital formation (% of GDP)              2.413030e+01
# AGO_Labor force, total                              1.226884e+07
# AGO_Population, total                               2.981675e+07
# AGO_Unemployment, total (% of total labor force...  7.119000e+00
#
#                                                             2018  \
# Pays_indic
# AGO_Exports of goods and services (% of GDP)        4.083629e+01
# AGO_Exports of goods and services (current mill...  4.138890e+04
# AGO_Exports of goods and services (current mill...  1.343370e-03
# AGO_Exports of goods and services (current mill...  3.257561e-03
# AGO_GDP (current million US$)                       1.013532e+05
# AGO_GDP per capita (current US$)                    3.289647e+03
# AGO_Gross capital formation (% of GDP)              1.786942e+01
# AGO_Labor force, total                              1.270549e+07
# AGO_Population, total                               3.080976e+07
# AGO_Unemployment, total (% of total labor force...  7.019000e+00
#
#                                                       Simple Indicator
# Pays_indic
# AGO_Exports of goods and services (% of GDP)              exports_rate
# AGO_Exports of goods and services (current mill...             exports
# AGO_Exports of goods and services (current mill...         exports_hab
# AGO_Exports of goods and services (current mill...  exports_labor_unit
# AGO_GDP (current million US$)                                      gdp
# AGO_GDP per capita (current US$)                               gdb_hab
# AGO_Gross capital formation (% of GDP)                            FBCF
# AGO_Labor force, total                                     labor_force
# AGO_Population, total                                              pop
# AGO_Unemployment, total (% of total labor force...   unemployment rate
#
# [10 rows x 23 columns]

# %% [markdown]
# On affiche le nombre de pays, et on vérifie qu'on a bien toujours la France, et on affiche la taille du df.

# %%
print('On a conservé ', len(dic_code.keys()), ' pays')
print('La taille du df est de ', df1.shape)
df1.loc[rech_ligne_pays('France', df1)]
# Out:
# On a conservé  145  pays
# La taille du df est de  (1450, 23)
#                                                    Country Name Country Code  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)             France          FRA
# FRA_Exports of goods and services (current mill...       France          FRA
# FRA_Exports of goods and services (current mill...       France          FRA
# FRA_Exports of goods and services (current mill...       France          FRA
# FRA_GDP (current million US$)                            France          FRA
# FRA_GDP per capita (current US$)                         France          FRA
# FRA_Gross capital formation (% of GDP)                   France          FRA
# FRA_Labor force, total                                   France          FRA
# FRA_Population, total                                    France          FRA
# FRA_Unemployment, total (% of total labor force...       France          FRA
#
#                                                                                        Indicator Name  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# FRA_Exports of goods and services (current mill...  Exports of goods and services (current million...
# FRA_Exports of goods and services (current mill...  _Exports of goods and services (current millio...
# FRA_Exports of goods and services (current mill...  _Exports of goods and services (current millio...
# FRA_GDP (current million US$)                                               GDP (current million US$)
# FRA_GDP per capita (current US$)                                         GDP per capita (current US$)
# FRA_Gross capital formation (% of GDP)                             Gross capital formation (% of GDP)
# FRA_Labor force, total                                                             Labor force, total
# FRA_Population, total                                                               Population, total
# FRA_Unemployment, total (% of total labor force...  Unemployment, total (% of total labor force) (...
#
#                                                             2000  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.859497e+01
# FRA_Exports of goods and services (current mill...  3.895347e+05
# FRA_Exports of goods and services (current mill...  6.394988e-03
# FRA_Exports of goods and services (current mill...  1.423671e-02
# FRA_GDP (current million US$)                       1.362249e+06
# FRA_GDP per capita (current US$)                    2.236403e+04
# FRA_Gross capital formation (% of GDP)              2.248805e+01
# FRA_Labor force, total                              2.736130e+07
# FRA_Population, total                               6.091250e+07
# FRA_Unemployment, total (% of total labor force...  1.021700e+01
#
#                                                             2001  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.826590e+01
# FRA_Exports of goods and services (current mill...  3.890702e+05
# FRA_Exports of goods and services (current mill...  6.341045e-03
# FRA_Exports of goods and services (current mill...  1.418445e-02
# FRA_GDP (current million US$)                       1.376465e+06
# FRA_GDP per capita (current US$)                    2.243356e+04
# FRA_Gross capital formation (% of GDP)              2.216487e+01
# FRA_Labor force, total                              2.742936e+07
# FRA_Population, total                               6.135743e+07
# FRA_Unemployment, total (% of total labor force...  8.610000e+00
#
#                                                             2002  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.753105e+01
# FRA_Exports of goods and services (current mill...  4.113928e+05
# FRA_Exports of goods and services (current mill...  6.656274e-03
# FRA_Exports of goods and services (current mill...  1.481840e-02
# FRA_GDP (current million US$)                       1.494287e+06
# FRA_GDP per capita (current US$)                    2.417734e+04
# FRA_Gross capital formation (% of GDP)              2.131558e+01
# FRA_Labor force, total                              2.776230e+07
# FRA_Population, total                               6.180527e+07
# FRA_Unemployment, total (% of total labor force...  8.702000e+00
#
#                                                             2003  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.611197e+01
# FRA_Exports of goods and services (current mill...  4.805858e+05
# FRA_Exports of goods and services (current mill...  7.720888e-03
# FRA_Exports of goods and services (current mill...  1.697049e-02
# FRA_GDP (current million US$)                       1.840481e+06
# FRA_GDP per capita (current US$)                    2.956839e+04
# FRA_Gross capital formation (% of GDP)              2.118613e+01
# FRA_Labor force, total                              2.831891e+07
# FRA_Population, total                               6.224489e+07
# FRA_Unemployment, total (% of total labor force...  8.306000e+00
#
#                                                             2004  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.646884e+01
# FRA_Exports of goods and services (current mill...  5.600124e+05
# FRA_Exports of goods and services (current mill...  8.930920e-03
# FRA_Exports of goods and services (current mill...  1.964856e-02
# FRA_GDP (current million US$)                       2.115742e+06
# FRA_GDP per capita (current US$)                    3.374127e+04
# FRA_Gross capital formation (% of GDP)              2.188960e+01
# FRA_Labor force, total                              2.850144e+07
# FRA_Population, total                               6.270490e+07
# FRA_Unemployment, total (% of total labor force...  8.914000e+00
#
#                                                             2005  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.703305e+01
# FRA_Exports of goods and services (current mill...  5.936799e+05
# FRA_Exports of goods and services (current mill...  9.396739e-03
# FRA_Exports of goods and services (current mill...  2.062555e-02
# FRA_GDP (current million US$)                       2.196126e+06
# FRA_GDP per capita (current US$)                    3.476019e+04
# FRA_Gross capital formation (% of GDP)              2.245262e+01
# FRA_Labor force, total                              2.878371e+07
# FRA_Population, total                               6.317935e+07
# FRA_Unemployment, total (% of total labor force...  8.493000e+00
#
#                                                             2006  ...  \
# Pays_indic                                                        ...
# FRA_Exports of goods and services (% of GDP)        2.793506e+01  ...
# FRA_Exports of goods and services (current mill...  6.477004e+05  ...
# FRA_Exports of goods and services (current mill...  1.018055e-02  ...
# FRA_Exports of goods and services (current mill...  2.238176e-02  ...
# FRA_GDP (current million US$)                       2.318594e+06  ...
# FRA_GDP per capita (current US$)                    3.644362e+04  ...
# FRA_Gross capital formation (% of GDP)              2.323771e+01  ...
# FRA_Labor force, total                              2.893876e+07  ...
# FRA_Population, total                               6.362138e+07  ...
# FRA_Unemployment, total (% of total labor force...  8.448000e+00  ...
#
#                                                             2010  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.678830e+01
# FRA_Exports of goods and services (current mill...  7.079102e+05
# FRA_Exports of goods and services (current mill...  1.088632e-02
# FRA_Exports of goods and services (current mill...  2.380105e-02
# FRA_GDP (current million US$)                       2.642610e+06
# FRA_GDP per capita (current US$)                    4.063833e+04
# FRA_Gross capital formation (% of GDP)              2.194629e+01
# FRA_Labor force, total                              2.974282e+07
# FRA_Population, total                               6.502751e+07
# FRA_Unemployment, total (% of total labor force...  8.871000e+00
#
#                                                             2011  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.842134e+01
# FRA_Exports of goods and services (current mill...  8.132505e+05
# FRA_Exports of goods and services (current mill...  1.244591e-02
# FRA_Exports of goods and services (current mill...  2.734086e-02
# FRA_GDP (current million US$)                       2.861408e+06
# FRA_GDP per capita (current US$)                    4.379073e+04
# FRA_Gross capital formation (% of GDP)              2.322091e+01
# FRA_Labor force, total                              2.974488e+07
# FRA_Population, total                               6.534278e+07
# FRA_Unemployment, total (% of total labor force...  8.811000e+00
#
#                                                             2012  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.920303e+01
# FRA_Exports of goods and services (current mill...  7.837582e+05
# FRA_Exports of goods and services (current mill...  1.193665e-02
# FRA_Exports of goods and services (current mill...  2.613852e-02
# FRA_GDP (current million US$)                       2.683825e+06
# FRA_GDP per capita (current US$)                    4.087470e+04
# FRA_Gross capital formation (% of GDP)              2.262663e+01
# FRA_Labor force, total                              2.998480e+07
# FRA_Population, total                               6.565981e+07
# FRA_Unemployment, total (% of total labor force...  9.400000e+00
#
#                                                             2013  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.936474e+01
# FRA_Exports of goods and services (current mill...  8.254656e+05
# FRA_Exports of goods and services (current mill...  1.250730e-02
# FRA_Exports of goods and services (current mill...  2.739995e-02
# FRA_GDP (current million US$)                       2.811078e+06
# FRA_GDP per capita (current US$)                    4.259293e+04
# FRA_Gross capital formation (% of GDP)              2.228719e+01
# FRA_Labor force, total                              3.012654e+07
# FRA_Population, total                               6.599869e+07
# FRA_Unemployment, total (% of total labor force...  9.921000e+00
#
#                                                             2014  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.966668e+01
# FRA_Exports of goods and services (current mill...  8.461430e+05
# FRA_Exports of goods and services (current mill...  1.276002e-02
# FRA_Exports of goods and services (current mill...  2.814089e-02
# FRA_GDP (current million US$)                       2.852166e+06
# FRA_GDP per capita (current US$)                    4.301126e+04
# FRA_Gross capital formation (% of GDP)              2.270983e+01
# FRA_Labor force, total                              3.006809e+07
# FRA_Population, total                               6.631207e+07
# FRA_Unemployment, total (% of total labor force...  1.029200e+01
#
#                                                             2015  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.059262e+01
# FRA_Exports of goods and services (current mill...  7.459117e+05
# FRA_Exports of goods and services (current mill...  1.120858e-02
# FRA_Exports of goods and services (current mill...  2.474985e-02
# FRA_GDP (current million US$)                       2.438208e+06
# FRA_GDP per capita (current US$)                    3.663818e+04
# FRA_Gross capital formation (% of GDP)              2.271232e+01
# FRA_Labor force, total                              3.013803e+07
# FRA_Population, total                               6.654827e+07
# FRA_Unemployment, total (% of total labor force...  1.035900e+01
#
#                                                             2016  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.024754e+01
# FRA_Exports of goods and services (current mill...  7.475030e+05
# FRA_Exports of goods and services (current mill...  1.120289e-02
# FRA_Exports of goods and services (current mill...  2.475404e-02
# FRA_GDP (current million US$)                       2.471286e+06
# FRA_GDP per capita (current US$)                    3.703737e+04
# FRA_Gross capital formation (% of GDP)              2.260939e+01
# FRA_Labor force, total                              3.019721e+07
# FRA_Population, total                               6.672410e+07
# FRA_Unemployment, total (% of total labor force...  1.005700e+01
#
#                                                             2017  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.094863e+01
# FRA_Exports of goods and services (current mill...  8.031638e+05
# FRA_Exports of goods and services (current mill...  1.201183e-02
# FRA_Exports of goods and services (current mill...  2.656276e-02
# FRA_GDP (current million US$)                       2.595151e+06
# FRA_GDP per capita (current US$)                    3.881216e+04
# FRA_Gross capital formation (% of GDP)              2.343619e+01
# FRA_Labor force, total                              3.023646e+07
# FRA_Population, total                               6.686438e+07
# FRA_Unemployment, total (% of total labor force...  9.397000e+00
#
#                                                             2018  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.171916e+01
# FRA_Exports of goods and services (current mill...  8.842869e+05
# FRA_Exports of goods and services (current mill...  1.320503e-02
# FRA_Exports of goods and services (current mill...  2.909621e-02
# FRA_GDP (current million US$)                       2.787864e+06
# FRA_GDP per capita (current US$)                    4.163109e+04
# FRA_Gross capital formation (% of GDP)              2.387174e+01
# FRA_Labor force, total                              3.039182e+07
# FRA_Population, total                               6.696591e+07
# FRA_Unemployment, total (% of total labor force...  9.059000e+00
#
#                                                       Simple Indicator
# Pays_indic
# FRA_Exports of goods and services (% of GDP)              exports_rate
# FRA_Exports of goods and services (current mill...             exports
# FRA_Exports of goods and services (current mill...         exports_hab
# FRA_Exports of goods and services (current mill...  exports_labor_unit
# FRA_GDP (current million US$)                                      gdp
# FRA_GDP per capita (current US$)                               gdb_hab
# FRA_Gross capital formation (% of GDP)                            FBCF
# FRA_Labor force, total                                     labor_force
# FRA_Population, total                                              pop
# FRA_Unemployment, total (% of total labor force...   unemployment rate
#
# [10 rows x 23 columns]

# %%
df1.to_csv('C:/Users/Titouan/Desktop/WB_data2.csv')
