# %% [markdown]
# Dans ce notebook, on indique la démarche suivie pour créer une base de donnée prête à être analysée à partir des indicateurs issus de la banque mondiale (https://data.worldbank.org/indicator/). On peut reprendre cette démarche pour rajouter ou enlever d'autres indicateurs, et on peut à la fin choisir de ne conserver que certains pays en en mettant la liste.
#
# La base créée dans ce code comporte ces indicateurs :
#
#     -Le pib en parité de pouvoir d'achat en dollars de 2017
#     -Le pib par habitant en parité de pouvoir d'achat en dollars de 2017
#     -les exportations en parité de pouvoir d'achat en dollars de 2017
#     -les exportations en parité de pouvoir d'achat en dollars de 2017 par habitant
#     -les exportations en parité de pouvoir d'achat en dollars de 2017 par unité de travail
#     -le taux d'exportation en pct du pib
#     -le taux de chomage en pct de la force de travail
#     -la population active
#     -la population
#     -la FBCF en pct du PIB
#     -la R&D en pct du pib
#     -les taxes payées par les entreprises en pct du profit commercial (détaillé en les trois variables ci-dessous)
#     -le taux d'imposition sur le profit en pct du profit commercial
#     -le taux de taxe sur le travail et cotisations sociales en pct du profit commercial
#     -les autres taxes payées par les entreprises en pct du profit commercial
#     -les IDE entrants en pct du pib

# %% [markdown]
# # Code

# %% [markdown]
# On commence par importer les modules nécessaires, et on crée quelques fonctions qui vont nous aider à manipuler les dataframe en jonglant entre les codes et les noms des pays

# %%
import pandas as pd
import re
import numpy as np

def refresh_dico(Name,Code,df):
    dico = {}
    for i in df[[Name,Code]].dropna().drop_duplicates().iterrows() :
        dico[i[1][Name]] = i[1][Code]
    return (dico)

def rech_ligne_pays (y,df) :
    expression = re.compile(dic_pays[y]+".*?;")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)+';'))))

def rech_ligne_indic (y,df):
    expression = re.compile(".{,4}"+y+";")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)+';'))))

# %% [markdown]
# On importe ensuite les bases au format csv, que l'on est allé chercher sur le site de la banque mondiale qui est en open data (https://data.worldbank.org/indicator/).
#
# Attention, pour ouvrir proprement ces données, il faut d'abord ouvrir les csv dans le bloc notes (ou n'importe quel autre logiciel capable de les ouvrir), et supprimer les deux premières lignes du document qui correspondent plus ou moins au titre du document, mais qui font bugger la fonction pd.read_csv.

# %%
#Importation des bases csv, et crétaion de la base aggrégée
gdp = pd.read_csv('pib_cst2017_ppp.csv')
gdp['Simple Indicator'] = 'gdp'

gdp_hab = pd.read_csv('pib_hab_cst2017_ppp.csv')
gdp_hab['Simple Indicator'] = 'gdb_hab'

fbcf = pd.read_csv('FBCF.csv')
fbcf['Simple Indicator'] = 'FBCF'

exports_rate = pd.read_csv('exports_rate.csv')
exports_rate['Simple Indicator'] = 'exports_rate'

unemployment_rate = pd.read_csv('unemployment_rate.csv')
unemployment_rate['Simple Indicator'] = 'unemployment rate'

pop = pd.read_csv('pop.csv')
pop['Simple Indicator'] = 'pop'

labor_force = pd.read_csv('labor force.csv')
labor_force ['Simple Indicator'] = 'labor_force'

ide = pd.read_csv('IDE.csv')
ide ['Simple Indicator'] = 'IDE'

labor_tax_contrib = pd.read_csv('labor_tax_contrib.csv')
labor_tax_contrib ['Simple Indicator'] = 'labor_tax_contrib'

other_taxes_entreprise = pd.read_csv('other_taxes.csv')
other_taxes_entreprise ['Simple Indicator'] = 'other_taxes_entreprise'

profit_tax = pd.read_csv('profit_tax.csv')
profit_tax ['Simple Indicator'] = 'profit_tax'

total_tax_contrib = pd.read_csv('total_tax_contrib.csv')
total_tax_contrib ['Simple Indicator'] = 'total_tax_contrib'

RetD = pd.read_csv('RetD.csv')
RetD ['Simple Indicator'] = 'RetD'

# %%
#création de la base aggrégée
df_list = [gdp, gdp_hab, fbcf, unemployment_rate, exports_rate, pop, labor_force, ide, 
           labor_tax_contrib, other_taxes_entreprise, profit_tax, total_tax_contrib, RetD]

for df in df_list :
    df['Pays_indic'] = df['Country Code'].str[:3] + '_' + df['Indicator Name'].str[:99]
df1 = pd.concat(df_list)
df1 = df1.sort_values('Pays_indic').set_index('Pays_indic')
df1.head(2)
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)              Aruba          ABW
# ABW_Foreign direct investment, net inflows (% o...        Aruba          ABW
#
#                                                                                        Indicator Name  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# ABW_Foreign direct investment, net inflows (% o...  Foreign direct investment, net inflows (% of GDP)
#
#                                                           Indicator Code  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)              NE.EXP.GNFS.ZS
# ABW_Foreign direct investment, net inflows (% o...  BX.KLT.DINV.WD.GD.ZS
#
#                                                     1960  1961  1962  1963  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)         NaN   NaN   NaN   NaN
# ABW_Foreign direct investment, net inflows (% o...   NaN   NaN   NaN   NaN
#
#                                                     1964  1965  ...  \
# Pays_indic                                                      ...
# ABW_Exports of goods and services (% of GDP)         NaN   NaN  ...
# ABW_Foreign direct investment, net inflows (% o...   NaN   NaN  ...
#
#                                                          2013       2014  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        76.509512  77.555556
# ABW_Foreign direct investment, net inflows (% o...   8.378924   9.062755
#
#                                                          2015       2016  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        73.517030  71.294029
# ABW_Foreign direct investment, net inflows (% o...  -0.985625   0.928928
#
#                                                          2017  2018  2019  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        73.332115   NaN   NaN
# ABW_Foreign direct investment, net inflows (% o...   5.315477   NaN   NaN
#
#                                                     2020  Unnamed: 65  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)         NaN          NaN
# ABW_Foreign direct investment, net inflows (% o...   NaN          NaN
#
#                                                     Simple Indicator
# Pays_indic
# ABW_Exports of goods and services (% of GDP)            exports_rate
# ABW_Foreign direct investment, net inflows (% o...               IDE
#
# [2 rows x 67 columns]

# %% [markdown]
# On supprime d'abord les colonnes qui ne nous servent à rien : le nom de code de l'indicateur, les années que l'on ne conserve pas pour l'étude, et la dernière colonne qui est un bug lors de l'ouverture de ces données avec la fonction pd.read_csv
#
# On fait ensuite de même avec les lignes, en supprimant tous les aggrégats de pays qui ne sont pas proprement des pays

# %%
#SUPPRESSION DES LIGNES ET COLONNES INUTILES
dic_pays = refresh_dico('Country Name','Country Code',df1)


useless_data_list = ['Unnamed: 65', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', 
                   '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', 
                   '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', 
                     '2019', '2020']
df1 = df1.drop(useless_data_list, axis = 1)


suppr_liste = ['Arab World', 'Central Europe and the Baltics',
 'Caribbean small states', 'East Asia & Pacific (excluding high income)', 
  'Early-demographic dividend', 
 'East Asia & Pacific',
 'Europe & Central Asia (excluding high income)', 
 'Europe & Central Asia',  
 'European Union','Fragile and conflict affected situations',
 'High income',
 'Heavily indebted poor countries (HIPC)','IBRD only',
 'IDA & IBRD total',
 'IDA total',
 'IDA blend',
 'IDA only',
 'Latin America & Caribbean (excluding high income)',
 'Latin America & Caribbean',
 'Least developed countries: UN classification',
 'Low income',
 'Lower middle income',
 'Low & middle income',
 'Late-demographic dividend',
 'Middle East & North Africa',
 'Middle income',
 'Middle East & North Africa (excluding high income)',
 'North America',
 'OECD members',
 'Other small states',
 'Pre-demographic dividend',
 'Pacific island small states',
 'Post-demographic dividend',
 'South Asia',
 'Sub-Saharan Africa (excluding high income)',
 'Sub-Saharan Africa',
 'Small states',
 'East Asia & Pacific (IDA & IBRD countries)',
 'Europe & Central Asia (IDA & IBRD countries)',
 'Latin America & the Caribbean (IDA & IBRD countries)',
 'Middle East & North Africa (IDA & IBRD countries)',
 'South Asia (IDA & IBRD)',
 'Sub-Saharan Africa (IDA & IBRD countries)',
 'Upper middle income',
 'World',
 'Central African Republic',
 'West Bank and Gaza',
 'Hong Kong SAR, China',
 'Macao SAR, China']
for i in suppr_liste :
    df1 = df1.drop(labels = rech_ligne_pays(i,df1))

# %% [markdown]
# On supprime maintenant tous les pays pour lesquels il manque au moins un indicateur. On le fait en deux étapes :
#
# (1) On supprime toutes les lignes où il manque au moins une donnée à un moment donné.
# (2) On supprime toutes les lignes de tous les pays pour lesquels on a supprimé au moins une ligne

# %%
dic_code = refresh_dico('Country Code','Country Name',df1)

for i in rech_ligne_pays(dic_code['USA'],df1):
    print(df1.loc[i])
# Out:
# Country Name                                   United States
# Country Code                                             USA
# Indicator Name      Exports of goods and services (% of GDP)
# 2005                                                  10.012
# 2006                                                 10.6598
# 2007                                                 11.4923
# 2008                                                 12.4861
# 2009                                                 10.9489
# 2010                                                 12.3151
# 2011                                                 13.5305
# 2012                                                 13.5289
# 2013                                                 13.5445
# 2014                                                 13.5316
# 2015                                                 12.4329
# 2016                                                 11.9005
# 2017                                                 12.1652
# 2018                                                 12.2871
# Simple Indicator                                exports_rate
# Name: USA_Exports of goods and services (% of GDP), dtype: object
# Country Name                                            United States
# Country Code                                                      USA
# Indicator Name      Foreign direct investment, net inflows (% of GDP)
# 2005                                                          1.09188
# 2006                                                          2.16049
# 2007                                                           2.3984
# 2008                                                          2.31833
# 2009                                                          1.11484
# 2010                                                          1.76119
# 2011                                                          1.69532
# 2012                                                          1.54563
# 2013                                                          1.71661
# 2014                                                          1.43695
# 2015                                                          2.80627
# 2016                                                          2.53481
# 2017                                                          1.88016
# 2018                                                          1.27055
# Simple Indicator                                                  IDE
# Name: USA_Foreign direct investment, net inflows (% of GDP), dtype: object
# Country Name                                            United States
# Country Code                                                      USA
# Indicator Name      GDP per capita, PPP (constant 2017 internation...
# 2005                                                          54395.4
# 2006                                                          55411.4
# 2007                                                          55916.7
# 2008                                                          55314.7
# 2009                                                          53440.9
# 2010                                                          54359.1
# 2011                                                          54806.1
# 2012                                                          55632.9
# 2013                                                            56270
# 2014                                                          57273.1
# 2015                                                          58509.6
# 2016                                                          59043.2
# 2017                                                          60062.2
# 2018                                                          61498.4
# Simple Indicator                                              gdb_hab
# Name: USA_GDP per capita, PPP (constant 2017 international $), dtype: object
# Country Name                                   United States
# Country Code                                             USA
# Indicator Name      GDP, PPP (constant 2017 international $)
# 2005                                             1.60747e+13
# 2006                                             1.65337e+13
# 2007                                             1.68439e+13
# 2008                                             1.68209e+13
# 2009                                             1.63942e+13
# 2010                                             1.68145e+13
# 2011                                             1.70752e+13
# 2012                                             1.74593e+13
# 2013                                              1.7781e+13
# 2014                                             1.82301e+13
# 2015                                             1.87602e+13
# 2016                                             1.90675e+13
# 2017                                             1.95194e+13
# 2018                                             2.00907e+13
# Simple Indicator                                         gdp
# Name: USA_GDP, PPP (constant 2017 international $), dtype: object
# Country Name                             United States
# Country Code                                       USA
# Indicator Name      Gross capital formation (% of GDP)
# 2005                                           23.3803
# 2006                                           23.5392
# 2007                                           22.5925
# 2008                                            21.119
# 2009                                           17.8046
# 2010                                           18.7431
# 2011                                           19.1035
# 2012                                           20.0209
# 2013                                           20.4137
# 2014                                           20.8062
# 2015                                           21.1787
# 2016                                           20.4477
# 2017                                           20.5717
# 2018                                           21.0725
# Simple Indicator                                  FBCF
# Name: USA_Gross capital formation (% of GDP), dtype: object
# Country Name             United States
# Country Code                       USA
# Indicator Name      Labor force, total
# 2005                       1.52072e+08
# 2006                       1.53931e+08
# 2007                       1.55225e+08
# 2008                       1.57007e+08
# 2009                       1.57109e+08
# 2010                       1.56903e+08
# 2011                       1.56975e+08
# 2012                       1.58636e+08
# 2013                       1.58756e+08
# 2014                       1.59532e+08
# 2015                       1.60596e+08
# 2016                       1.62548e+08
# 2017                       1.64268e+08
# 2018                       1.65483e+08
# Simple Indicator           labor_force
# Name: USA_Labor force, total, dtype: object
# Country Name            United States
# Country Code                      USA
# Indicator Name      Population, total
# 2005                      2.95517e+08
# 2006                       2.9838e+08
# 2007                      3.01231e+08
# 2008                      3.04094e+08
# 2009                      3.06772e+08
# 2010                      3.09322e+08
# 2011                      3.11557e+08
# 2012                      3.13831e+08
# 2013                      3.15994e+08
# 2014                      3.18301e+08
# 2015                      3.20635e+08
# 2016                      3.22941e+08
# 2017                      3.24986e+08
# 2018                      3.26688e+08
# Simple Indicator                  pop
# Name: USA_Population, total, dtype: object
# Country Name                                          United States
# Country Code                                                    USA
# Indicator Name      Research and development expenditure (% of GDP)
# 2005                                                        2.51697
# 2006                                                        2.55764
# 2007                                                        2.63161
# 2008                                                        2.76791
# 2009                                                         2.8127
# 2010                                                         2.7354
# 2011                                                        2.76525
# 2012                                                        2.68166
# 2013                                                        2.70972
# 2014                                                        2.71924
# 2015                                                        2.71742
# 2016                                                        2.76145
# 2017                                                        2.81741
# 2018                                                        2.83766
# Simple Indicator                                               RetD
# Name: USA_Research and development expenditure (% of GDP), dtype: object
# Country Name                                            United States
# Country Code                                                      USA
# Indicator Name      Unemployment, total (% of total labor force) (...
# 2005                                                            5.083
# 2006                                                            4.623
# 2007                                                            4.622
# 2008                                                            5.784
# 2009                                                            9.254
# 2010                                                            9.633
# 2011                                                            8.949
# 2012                                                            8.069
# 2013                                                            7.375
# 2014                                                            6.168
# 2015                                                             5.28
# 2016                                                            4.869
# 2017                                                            4.355
# 2018                                                            3.896
# Simple Indicator                                    unemployment rate
# Name: USA_Unemployment, total (% of total labor force) (modeled ILO estimate), dtype: object

# %%
#Étape 1
df1 = df1.dropna(axis = 0)
df1.head(7)
print (df1.shape)
#Étape 2 
dic_code = refresh_dico('Country Code','Country Name',df1)

for i in dic_pays.keys() :
    if len(rech_ligne_pays(i,df1)) < len(df_list) :
        df1 = df1.drop(rech_ligne_pays(i,df1))

dic_code = refresh_dico('Country Code','Country Name',df1)

#On affiche le nombre de pays restant dans la base
print(len(dic_code.keys()))
# Out:
# (1507, 18)
# 50

# %% [markdown]
# On recrée maintenant la variable correpondant aux exportations par pays en dollars, à partir du PIB et des exportations en pourcentage du PIB.
#
# Après l'avoir fait, on peut supprimer l'ancienne variable qui exprime les exportations en pct du PIB en enlevant le # sur la ligne correspondante.
#
# On a utlisé la formule :
#
#     Exportation$ = (Exportations%PIB * PIB)/100

# %%
#CREATION DE LA VARIABLE EXPORTATION A PARTIR DE EXPORTATION RATE ET DU PIB

for i in dic_code.keys():
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)']= (df1.loc[i+'_Exports of goods and services (% of GDP)'][3:df1.shape[1]-1].astype(np.float64) * df1.loc[i+'_GDP, PPP (constant 2017 international $)'][3:df1.shape[1]-1].astype(np.float64)) / 100
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)',['Country Name','Country Code']]=df1.loc[i+'_Exports of goods and services (% of GDP)',['Country Name','Country Code']]
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)','Indicator Name']= 'Exports of goods and services, PPP (constant 2017 international $)'
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)','Simple Indicator'] = 'exports'
    #df1 = df1.drop(labels = i+'_Exports of goods and services (% of GDP)')
df1 = df1.sort_index()

# %% [markdown]
# On va maintenant créer les variables par habitant, et par population active

# %%
def gen_per_capita(variable):
    for i in dic_code.keys():
        df1.loc[i+variable+' per capita']= df1.loc[i+variable][3:df1.shape[1]-1].astype(np.float64) / df1.loc[i+'_Population, total'][3:df1.shape[1]-1].astype(np.float64)
        df1.loc[i+variable+' per capita',['Country Name','Country Code']]=df1.loc[i+variable,['Country Name','Country Code']]
        df1.loc[i+variable+' per capita','Indicator Name']= variable + ' per capita'
        df1.loc[i+variable+' per capita','Simple Indicator'] = df1.loc[i+variable, 'Simple Indicator'] + '_hab'
    return
gen_per_capita('_Exports of goods and services, PPP (constant 2017 international $)')

def gen_per_labor_unit(variable) :
    for i in dic_code.keys():
        df1.loc[i+variable+' per labor unit']= df1.loc[i+variable][3:df1.shape[1]-1].astype(np.float64) / df1.loc[i+'_Labor force, total'][3:df1.shape[1]-1].astype(np.float64)
        df1.loc[i+variable+' per labor unit',['Country Name','Country Code']]=df1.loc[i+variable,['Country Name','Country Code']]
        df1.loc[i+variable+' per labor unit','Indicator Name']= variable + ' per labor unit'
        df1.loc[i+variable+' per labor unit','Simple Indicator'] = df1.loc[i+variable, 'Simple Indicator'] + '_labor_unit'
    return
gen_per_labor_unit('_Exports of goods and services, PPP (constant 2017 international $)')
df1 = df1.sort_index()

# %%
df1.head(10)
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)            Armenia          ARM
# ARM_Exports of goods and services, PPP (constan...      Armenia          ARM
# ARM_Exports of goods and services, PPP (constan...      Armenia          ARM
# ARM_Exports of goods and services, PPP (constan...      Armenia          ARM
# ARM_Foreign direct investment, net inflows (% o...      Armenia          ARM
# ARM_GDP per capita, PPP (constant 2017 internat...      Armenia          ARM
# ARM_GDP, PPP (constant 2017 international $)            Armenia          ARM
# ARM_Gross capital formation (% of GDP)                  Armenia          ARM
# ARM_Labor force, total                                  Armenia          ARM
# ARM_Labor tax and contributions (% of commercia...      Armenia          ARM
#
#                                                                                        Indicator Name  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# ARM_Exports of goods and services, PPP (constan...  Exports of goods and services, PPP (constant 2...
# ARM_Exports of goods and services, PPP (constan...  _Exports of goods and services, PPP (constant ...
# ARM_Exports of goods and services, PPP (constan...  _Exports of goods and services, PPP (constant ...
# ARM_Foreign direct investment, net inflows (% o...  Foreign direct investment, net inflows (% of GDP)
# ARM_GDP per capita, PPP (constant 2017 internat...  GDP per capita, PPP (constant 2017 internation...
# ARM_GDP, PPP (constant 2017 international $)                 GDP, PPP (constant 2017 international $)
# ARM_Gross capital formation (% of GDP)                             Gross capital formation (% of GDP)
# ARM_Labor force, total                                                             Labor force, total
# ARM_Labor tax and contributions (% of commercia...  Labor tax and contributions (% of commercial p...
#
#                                                             2005  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.731320e+01
# ARM_Exports of goods and services, PPP (constan...  6.041838e+09
# ARM_Exports of goods and services, PPP (constan...  2.026599e+03
# ARM_Exports of goods and services, PPP (constan...  4.905307e+03
# ARM_Foreign direct investment, net inflows (% o...  5.960106e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  7.419854e+03
# ARM_GDP, PPP (constant 2017 international $)        2.212058e+10
# ARM_Gross capital formation (% of GDP)              3.576544e+01
# ARM_Labor force, total                              1.231694e+06
# ARM_Labor tax and contributions (% of commercia...  1.990000e+01
#
#                                                             2006  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.214598e+01
# ARM_Exports of goods and services, PPP (constan...  5.545464e+09
# ARM_Exports of goods and services, PPP (constan...  1.874540e+03
# ARM_Exports of goods and services, PPP (constan...  4.492542e+03
# ARM_Foreign direct investment, net inflows (% o...  7.307315e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  8.464469e+03
# ARM_GDP, PPP (constant 2017 international $)        2.504050e+10
# ARM_Gross capital formation (% of GDP)              4.222546e+01
# ARM_Labor force, total                              1.234371e+06
# ARM_Labor tax and contributions (% of commercia...  1.990000e+01
#
#                                                             2007  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        1.818936e+01
# ARM_Exports of goods and services, PPP (constan...  5.178700e+09
# ARM_Exports of goods and services, PPP (constan...  1.765897e+03
# ARM_Exports of goods and services, PPP (constan...  4.179897e+03
# ARM_Foreign direct investment, net inflows (% o...  7.252332e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  9.708405e+03
# ARM_GDP, PPP (constant 2017 international $)        2.847104e+10
# ARM_Gross capital formation (% of GDP)              4.435162e+01
# ARM_Labor force, total                              1.238954e+06
# ARM_Labor tax and contributions (% of commercia...  2.300000e+01
#
#                                                             2008  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        1.426573e+01
# ARM_Exports of goods and services, PPP (constan...  4.341853e+09
# ARM_Exports of goods and services, PPP (constan...  1.493268e+03
# ARM_Exports of goods and services, PPP (constan...  3.492981e+03
# ARM_Foreign direct investment, net inflows (% o...  8.092349e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.046752e+04
# ARM_GDP, PPP (constant 2017 international $)        3.043555e+10
# ARM_Gross capital formation (% of GDP)              4.794284e+01
# ARM_Labor force, total                              1.243022e+06
# ARM_Labor tax and contributions (% of commercia...  2.300000e+01
#
#                                                             2009  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        1.467090e+01
# ARM_Exports of goods and services, PPP (constan...  3.835580e+09
# ARM_Exports of goods and services, PPP (constan...  1.328067e+03
# ARM_Exports of goods and services, PPP (constan...  3.061103e+03
# ARM_Foreign direct investment, net inflows (% o...  8.788695e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  9.052390e+03
# ARM_GDP, PPP (constant 2017 international $)        2.614413e+10
# ARM_Gross capital formation (% of GDP)              4.114505e+01
# ARM_Labor force, total                              1.253006e+06
# ARM_Labor tax and contributions (% of commercia...  2.300000e+01
#
#                                                             2010  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        1.974842e+01
# ARM_Exports of goods and services, PPP (constan...  5.276639e+09
# ARM_Exports of goods and services, PPP (constan...  1.833874e+03
# ARM_Exports of goods and services, PPP (constan...  4.027366e+03
# ARM_Foreign direct investment, net inflows (% o...  5.716038e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  9.286181e+03
# ARM_GDP, PPP (constant 2017 international $)        2.671931e+10
# ARM_Gross capital formation (% of GDP)              3.881475e+01
# ARM_Labor force, total                              1.310196e+06
# ARM_Labor tax and contributions (% of commercia...  2.300000e+01
#
#                                                             2011  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.252319e+01
# ARM_Exports of goods and services, PPP (constan...  6.300887e+09
# ARM_Exports of goods and services, PPP (constan...  2.190441e+03
# ARM_Exports of goods and services, PPP (constan...  4.696130e+03
# ARM_Foreign direct investment, net inflows (% o...  6.440668e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  9.725271e+03
# ARM_GDP, PPP (constant 2017 international $)        2.797511e+10
# ARM_Gross capital formation (% of GDP)              3.192180e+01
# ARM_Labor force, total                              1.341719e+06
# ARM_Labor tax and contributions (% of commercia...  2.300000e+01
#
#                                                             2012  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.756181e+01
# ARM_Exports of goods and services, PPP (constan...  8.265600e+09
# ARM_Exports of goods and services, PPP (constan...  2.865792e+03
# ARM_Exports of goods and services, PPP (constan...  6.118040e+03
# ARM_Foreign direct investment, net inflows (% o...  4.676728e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.039769e+04
# ARM_GDP, PPP (constant 2017 international $)        2.998932e+10
# ARM_Gross capital formation (% of GDP)              2.468095e+01
# ARM_Labor force, total                              1.351021e+06
# ARM_Labor tax and contributions (% of commercia...  2.300000e+01
#
#                                                             2013  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.835349e+01
# ARM_Exports of goods and services, PPP (constan...  8.783617e+09
# ARM_Exports of goods and services, PPP (constan...  3.031359e+03
# ARM_Exports of goods and services, PPP (constan...  6.456880e+03
# ARM_Foreign direct investment, net inflows (% o...  3.111931e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.069131e+04
# ARM_GDP, PPP (constant 2017 international $)        3.097897e+10
# ARM_Gross capital formation (% of GDP)              2.215249e+01
# ARM_Labor force, total                              1.360350e+06
# ARM_Labor tax and contributions (% of commercia...  1.940000e+01
#
#                                                             2014  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.856038e+01
# ARM_Exports of goods and services, PPP (constan...  9.166229e+09
# ARM_Exports of goods and services, PPP (constan...  3.147308e+03
# ARM_Exports of goods and services, PPP (constan...  6.799465e+03
# ARM_Foreign direct investment, net inflows (% o...  3.502114e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.101984e+04
# ARM_GDP, PPP (constant 2017 international $)        3.209421e+10
# ARM_Gross capital formation (% of GDP)              2.128304e+01
# ARM_Labor force, total                              1.348081e+06
# ARM_Labor tax and contributions (% of commercia...  0.000000e+00
#
#                                                             2015  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        2.972539e+01
# ARM_Exports of goods and services, PPP (constan...  9.845414e+09
# ARM_Exports of goods and services, PPP (constan...  3.365317e+03
# ARM_Exports of goods and services, PPP (constan...  7.376085e+03
# ARM_Foreign direct investment, net inflows (% o...  1.744737e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.132136e+04
# ARM_GDP, PPP (constant 2017 international $)        3.312123e+10
# ARM_Gross capital formation (% of GDP)              2.073053e+01
# ARM_Labor force, total                              1.334775e+06
# ARM_Labor tax and contributions (% of commercia...  0.000000e+00
#
#                                                             2016  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        3.374428e+01
# ARM_Exports of goods and services, PPP (constan...  1.119887e+10
# ARM_Exports of goods and services, PPP (constan...  3.814140e+03
# ARM_Exports of goods and services, PPP (constan...  8.548359e+03
# ARM_Foreign direct investment, net inflows (% o...  3.164508e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.130307e+04
# ARM_GDP, PPP (constant 2017 international $)        3.318747e+10
# ARM_Gross capital formation (% of GDP)              1.801551e+01
# ARM_Labor force, total                              1.310061e+06
# ARM_Labor tax and contributions (% of commercia...  0.000000e+00
#
#                                                             2017  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        3.821605e+01
# ARM_Exports of goods and services, PPP (constan...  1.363416e+10
# ARM_Exports of goods and services, PPP (constan...  4.629896e+03
# ARM_Exports of goods and services, PPP (constan...  1.045843e+04
# ARM_Foreign direct investment, net inflows (% o...  2.176847e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.211506e+04
# ARM_GDP, PPP (constant 2017 international $)        3.567653e+10
# ARM_Gross capital formation (% of GDP)              1.842174e+01
# ARM_Labor force, total                              1.303653e+06
# ARM_Labor tax and contributions (% of commercia...  0.000000e+00
#
#                                                             2018  \
# Pays_indic
# ARM_Exports of goods and services (% of GDP)        3.939289e+01
# ARM_Exports of goods and services, PPP (constan...  1.478483e+10
# ARM_Exports of goods and services, PPP (constan...  5.008790e+03
# ARM_Exports of goods and services, PPP (constan...  1.134595e+04
# ARM_Foreign direct investment, net inflows (% o...  2.040033e+00
# ARM_GDP per capita, PPP (constant 2017 internat...  1.271496e+04
# ARM_GDP, PPP (constant 2017 international $)        3.753171e+10
# ARM_Gross capital formation (% of GDP)              2.239974e+01
# ARM_Labor force, total                              1.303093e+06
# ARM_Labor tax and contributions (% of commercia...  0.000000e+00
#
#                                                       Simple Indicator
# Pays_indic
# ARM_Exports of goods and services (% of GDP)              exports_rate
# ARM_Exports of goods and services, PPP (constan...             exports
# ARM_Exports of goods and services, PPP (constan...         exports_hab
# ARM_Exports of goods and services, PPP (constan...  exports_labor_unit
# ARM_Foreign direct investment, net inflows (% o...                 IDE
# ARM_GDP per capita, PPP (constant 2017 internat...             gdb_hab
# ARM_GDP, PPP (constant 2017 international $)                       gdp
# ARM_Gross capital formation (% of GDP)                            FBCF
# ARM_Labor force, total                                     labor_force
# ARM_Labor tax and contributions (% of commercia...   labor_tax_contrib

# %% [markdown]
# On affiche le nombre de pays, et on vérifie qu'on a bien toujours la France, et on affiche la taille du df.

# %%
print('On a conservé ', len(dic_code.keys()), ' pays')
print('La taille du df est de ', df1.shape)
df1.loc[rech_ligne_pays('France', df1)]
dic_code.keys()
# Out:
# On a conservé  41  pays
# La taille du df est de  (656, 18)
# dict_keys(['ARM', 'AUT', 'AZE', 'BEL', 'BGR', 'BLR', 'CAN', 'COL', 'CZE', 'DEU', 'DNK', 'EGY', 'EMU', 'ESP', 'EST', 'FIN', 'FRA', 'GBR', 'GRC', 'HRV', 'HUN', 'ISR', 'ITA', 'KAZ', 'KOR', 'KWT', 'LTU', 'LVA', 'MDA', 'MKD', 'MNG', 'NLD', 'NOR', 'POL', 'PRT', 'ROU', 'SVK', 'SVN', 'SWE', 'UKR', 'UZB'])

# %%
df1.to_csv('C:/Users/Titouan/Desktop/WB_extended_data.csv')

# %% [markdown]
# ###Récupération des bases de codes des noms de pays

# %%
import urllib#pour récupérer les données
import bs4#pour rendre lisibles les données

# %%
def Scrap (url):
    req = urllib.request.Request(url)
    html = urllib.request.urlopen(req).read()
    page = bs4.BeautifulSoup(html, "lxml")
    return page

# %%
def ToDf (table) :
    Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
    listeDf=Listgrossiere[0]#on récupère le dataframe
    return listeDf

# %%
page=Scrap('https://laendercode.net/fr/2-letter-list.html')
table = page.find('table')
liste2=ToDf(table)

# %%
page=Scrap('https://laendercode.net/fr/3-letter-list.html')
table = page.find('table')
liste3=ToDf(table)

# %%
liste2.to_csv(r'C:\Users\sylva\Desktop\git\Statap_cice\liste_pays_2lettres.csv')
liste3.to_csv(r'C:\Users\sylva\Desktop\git\Statap_cice\liste_pays_3lettres.csv')
