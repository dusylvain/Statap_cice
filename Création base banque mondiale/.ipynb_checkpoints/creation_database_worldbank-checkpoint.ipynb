# %% [markdown]
# Dans ce notebook, on indique la démarche suivie pour créer une base de donnée prête à être analysée à partir des indicateurs issus de la banque mondiale (https://data.worldbank.org/indicator/). On peut reprendre cette démarche pour rajouter ou enlever d'autres indicateurs, et on peut à la fin choisir de ne conserver que certains pays en en mettant la liste.
#
# La base créée dans ce code comporte ces indicateurs :
#
#     -Le pib en parité de pouvoir d'achat en dollars de 2017
#     -Le pib par habitant en parité de pouvoir d'achat en dollars de 2017
#     -les exportations en parité de pouvoir d'achat en dollars de 2017
#     -les exportations en parité de pouvoir d'achat en dollars de 2017 par habitant
#     -les exportations en parité de pouvoir d'achat en dollars de 2017 par unité de travail
#     -le taux d'exportation en pct du pib
#     -le taux de chomage en pct de la force de travail
#     -la population active
#     -la population
#     -la FBCF en pct du PIB

# %% [markdown]
# # Code

# %% [markdown]
# On commence par importer les modules nécessaires, et on crée quelques foncions qui vont nous aider à manipuler les dataframe en jonglant entre les codes et les noms des pays

# %%
import pandas as pd
import re
import numpy as np

def refresh_dico(Name,Code,df):
    dico = {}
    for i in df[[Name,Code]].dropna().drop_duplicates().iterrows() :
        dico[i[1][Name]] = i[1][Code]
    return (dico)

def rech_ligne_pays (y,df) :
    expression = re.compile(dic_pays[y]+".*?;")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)+';'))))

def rech_ligne_indic (y,df):
    expression = re.compile(".{,4}"+y+";")
    return(list(i[:-1] for i in (expression.findall(';'.join(df.index)+';'))))

# %% [markdown]
# On importe ensuite les bases au format csv, que l'on est allé chercher sur le site de la banque mondiale qui est en open data (https://data.worldbank.org/indicator/).
#
# Attention, pour ouvrir proprement ces données, il faut d'abord ouvrir les csv dans le bloc notes (ou n'importe quel autre logiciel capable de les ouvrir), et supprimer les deux premières lignes du document qui correspondent plus ou moins au titre du document, mais qui font bugger la fonction pd.read_csv.

# %%
#Importation des bases csv, et crétaion de la base aggrégée
gdp = pd.read_csv('pib_cst2017_ppp.csv')
gdp['Simple Indicator'] = 'gdp'

gdp_hab = pd.read_csv('pib_hab_cst2017_ppp.csv')
gdp_hab['Simple Indicator'] = 'gdb_hab'

fbcf = pd.read_csv('FBCF.csv')
fbcf['Simple Indicator'] = 'FBCF'

exports_rate = pd.read_csv('exports_rate.csv')
exports_rate['Simple Indicator'] = 'exports_rate'

unemployment_rate = pd.read_csv('unemployment_rate.csv')
unemployment_rate['Simple Indicator'] = 'unemployment rate'

pop = pd.read_csv('pop.csv')
pop['Simple Indicator'] = 'pop'

labor_force = pd.read_csv('labor force.csv')
labor_force ['Simple Indicator'] = 'labor_force'

# %%
#création de la base aggrégée
df_list = [gdp, gdp_hab, fbcf, unemployment_rate, exports_rate, pop, labor_force]

for df in df_list :
    df['Pays_indic'] = df['Country Code'].str[:3] + '_' + df['Indicator Name'].str[:99]
df1 = pd.concat(df_list)
df1 = df1.sort_values('Pays_indic').set_index('Pays_indic')
df1.head(3)
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)              Aruba          ABW
# ABW_GDP per capita, PPP (constant 2017 internat...        Aruba          ABW
# ABW_GDP, PPP (constant 2017 international $)              Aruba          ABW
#
#                                                                                        Indicator Name  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# ABW_GDP per capita, PPP (constant 2017 internat...  GDP per capita, PPP (constant 2017 internation...
# ABW_GDP, PPP (constant 2017 international $)                 GDP, PPP (constant 2017 international $)
#
#                                                        Indicator Code  1960  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)           NE.EXP.GNFS.ZS   NaN
# ABW_GDP per capita, PPP (constant 2017 internat...  NY.GDP.PCAP.PP.KD   NaN
# ABW_GDP, PPP (constant 2017 international $)        NY.GDP.MKTP.PP.KD   NaN
#
#                                                     1961  1962  1963  1964  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)         NaN   NaN   NaN   NaN
# ABW_GDP per capita, PPP (constant 2017 internat...   NaN   NaN   NaN   NaN
# ABW_GDP, PPP (constant 2017 international $)         NaN   NaN   NaN   NaN
#
#                                                     1965  ...          2013  \
# Pays_indic                                                ...
# ABW_Exports of goods and services (% of GDP)         NaN  ...  7.650951e+01
# ABW_GDP per capita, PPP (constant 2017 internat...   NaN  ...  3.556331e+04
# ABW_GDP, PPP (constant 2017 international $)         NaN  ...  3.668676e+09
#
#                                                             2014  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        7.755556e+01
# ABW_GDP per capita, PPP (constant 2017 internat...  3.545861e+04
# ABW_GDP, PPP (constant 2017 international $)        3.679682e+09
#
#                                                             2015  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        7.351703e+01
# ABW_GDP per capita, PPP (constant 2017 internat...  3.727608e+04
# ABW_GDP, PPP (constant 2017 international $)        3.889424e+09
#
#                                                             2016  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        7.129403e+01
# ABW_GDP per capita, PPP (constant 2017 internat...  3.786617e+04
# ABW_GDP, PPP (constant 2017 international $)        3.971101e+09
#
#                                                             2017  2018  2019  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)        7.333211e+01   NaN   NaN
# ABW_GDP per capita, PPP (constant 2017 internat...  3.844241e+04   NaN   NaN
# ABW_GDP, PPP (constant 2017 international $)        4.050523e+09   NaN   NaN
#
#                                                     2020  Unnamed: 65  \
# Pays_indic
# ABW_Exports of goods and services (% of GDP)         NaN          NaN
# ABW_GDP per capita, PPP (constant 2017 internat...   NaN          NaN
# ABW_GDP, PPP (constant 2017 international $)         NaN          NaN
#
#                                                     Simple Indicator
# Pays_indic
# ABW_Exports of goods and services (% of GDP)            exports_rate
# ABW_GDP per capita, PPP (constant 2017 internat...           gdb_hab
# ABW_GDP, PPP (constant 2017 international $)                     gdp
#
# [3 rows x 67 columns]

# %% [markdown]
# On supprime d'abord les colonnes qui ne nous servent à rien : le nom de code de l'indicateur, les années que l'on ne conserve pas pour l'étude, et la dernière colonne qui est un bug lors de l'ouverture de ces données avec la fonction pd.read_csv
#
# On fait ensuite de même avec les lignes, en supprimant tous les aggrégats de pays qui ne sont pas proprement des pays

# %%
#SUPPRESSION DES LIGNES ET COLONNES INUTILES
dic_pays = refresh_dico('Country Name','Country Code',df1)


useless_data_list = ['Unnamed: 65', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', 
                   '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', 
                   '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
                   '2019', '2020']
df1 = df1.drop(useless_data_list, axis = 1)


suppr_liste = ['Arab World', 'Central Europe and the Baltics',
 'Caribbean small states', 'East Asia & Pacific (excluding high income)', 
  'Early-demographic dividend', 
 'East Asia & Pacific',
 'Europe & Central Asia (excluding high income)', 
 'Europe & Central Asia',  
 'European Union','Fragile and conflict affected situations',
 'High income',
 'Heavily indebted poor countries (HIPC)','IBRD only',
 'IDA & IBRD total',
 'IDA total',
 'IDA blend',
 'IDA only',
 'Latin America & Caribbean (excluding high income)',
 'Latin America & Caribbean',
 'Least developed countries: UN classification',
 'Low income',
 'Lower middle income',
 'Low & middle income',
 'Late-demographic dividend',
 'Middle East & North Africa',
 'Middle income',
 'Middle East & North Africa (excluding high income)',
 'North America',
 'OECD members',
 'Other small states',
 'Pre-demographic dividend',
 'Pacific island small states',
 'Post-demographic dividend',
 'South Asia',
 'Sub-Saharan Africa (excluding high income)',
 'Sub-Saharan Africa',
 'Small states',
 'East Asia & Pacific (IDA & IBRD countries)',
 'Europe & Central Asia (IDA & IBRD countries)',
 'Latin America & the Caribbean (IDA & IBRD countries)',
 'Middle East & North Africa (IDA & IBRD countries)',
 'South Asia (IDA & IBRD)',
 'Sub-Saharan Africa (IDA & IBRD countries)',
 'Upper middle income',
 'World',
 'Central African Republic',
 'West Bank and Gaza',
 'Hong Kong SAR, China',
 'Macao SAR, China']
for i in suppr_liste :
    df1 = df1.drop(labels = rech_ligne_pays(i,df1))

# %% [markdown]
# On supprime maintenant tous les pays pour lesquels il manque au moins un indicateur. On le fait en deux étapes :
#
# (1) On supprime toutes les lignes où il manque au moins une donnée à un moment donné.
# (2) On supprime toutes les lignes de tous les pays pour lesquels on a supprimé au moins une ligne

# %%
#Étape 1
df1 = df1.dropna(axis = 0)
df1.head(7)

#Étape 2 
dic_code = refresh_dico('Country Code','Country Name',df1)

for i in dic_pays.keys() :
    if len(rech_ligne_pays(i,df1)) < len(df_list) :
        df1 = df1.drop(rech_ligne_pays(i,df1))

dic_code = refresh_dico('Country Code','Country Name',df1)

#On affiche le nombre de pays restant dans la base
print(len(dic_code.keys()))
# Out:
# 138

# %% [markdown]
# On recrée maintenant la variable correpondant aux exportations par pays en dollars, à partir du PIB et des exportations en pourcentage du PIB.
#
# Après l'avoir fait, on peut supprimer l'ancienne variable qui exprime les exportations en pct du PIB en enlevant le # sur la ligne correspondante.
#
# On a utlisé la formule :
#
#     Exportation$ = (Exportations%PIB * PIB)/100

# %%
#CREATION DE LA VARIABLE EXPORTATION A PARTIR DE EXPORTATION RATE ET DU PIB

for i in dic_code.keys():
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)']= (df1.loc[i+'_Exports of goods and services (% of GDP)'][3:df1.shape[1]-1].astype(np.float64) * df1.loc[i+'_GDP, PPP (constant 2017 international $)'][3:df1.shape[1]-1].astype(np.float64)) / 100
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)',['Country Name','Country Code']]=df1.loc[i+'_Exports of goods and services (% of GDP)',['Country Name','Country Code']]
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)','Indicator Name']= 'Exports of goods and services, PPP (constant 2017 international $)'
    df1.loc[i+ '_Exports of goods and services, PPP (constant 2017 international $)','Simple Indicator'] = 'exports'
    #df1 = df1.drop(labels = i+'_Exports of goods and services (% of GDP)')
df1 = df1.sort_index()

# %% [markdown]
# On va maintenant créer les variables par habitant, et par population active

# %%
def gen_per_capita(variable):
    for i in dic_code.keys():
        df1.loc[i+variable+' per capita']= df1.loc[i+variable][3:df1.shape[1]-1].astype(np.float64) / df1.loc[i+'_Population, total'][3:df1.shape[1]-1].astype(np.float64)
        df1.loc[i+variable+' per capita',['Country Name','Country Code']]=df1.loc[i+variable,['Country Name','Country Code']]
        df1.loc[i+variable+' per capita','Indicator Name']= variable + ' per capita'
        df1.loc[i+variable+' per capita','Simple Indicator'] = df1.loc[i+variable, 'Simple Indicator'] + '_hab'
    return
gen_per_capita('_Exports of goods and services, PPP (constant 2017 international $)')

def gen_per_labor_unit(variable) :
    for i in dic_code.keys():
        df1.loc[i+variable+' per labor unit']= df1.loc[i+variable][3:df1.shape[1]-1].astype(np.float64) / df1.loc[i+'_Labor force, total'][3:df1.shape[1]-1].astype(np.float64)
        df1.loc[i+variable+' per labor unit',['Country Name','Country Code']]=df1.loc[i+variable,['Country Name','Country Code']]
        df1.loc[i+variable+' per labor unit','Indicator Name']= variable + ' per labor unit'
        df1.loc[i+variable+' per labor unit','Simple Indicator'] = df1.loc[i+variable, 'Simple Indicator'] + '_labor_unit'
    return
gen_per_labor_unit('_Exports of goods and services, PPP (constant 2017 international $)')
df1 = df1.sort_index()

# %%
df1.head(10)
# Out:
#                                                    Country Name Country Code  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)            Albania          ALB
# ALB_Exports of goods and services, PPP (constan...      Albania          ALB
# ALB_Exports of goods and services, PPP (constan...      Albania          ALB
# ALB_Exports of goods and services, PPP (constan...      Albania          ALB
# ALB_GDP per capita, PPP (constant 2017 internat...      Albania          ALB
# ALB_GDP, PPP (constant 2017 international $)            Albania          ALB
# ALB_Gross capital formation (% of GDP)                  Albania          ALB
# ALB_Labor force, total                                  Albania          ALB
# ALB_Population, total                                   Albania          ALB
# ALB_Unemployment, total (% of total labor force...      Albania          ALB
#
#                                                                                        Indicator Name  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# ALB_Exports of goods and services, PPP (constan...  Exports of goods and services, PPP (constant 2...
# ALB_Exports of goods and services, PPP (constan...  _Exports of goods and services, PPP (constant ...
# ALB_Exports of goods and services, PPP (constan...  _Exports of goods and services, PPP (constant ...
# ALB_GDP per capita, PPP (constant 2017 internat...  GDP per capita, PPP (constant 2017 internation...
# ALB_GDP, PPP (constant 2017 international $)                 GDP, PPP (constant 2017 international $)
# ALB_Gross capital formation (% of GDP)                             Gross capital formation (% of GDP)
# ALB_Labor force, total                                                             Labor force, total
# ALB_Population, total                                                               Population, total
# ALB_Unemployment, total (% of total labor force...  Unemployment, total (% of total labor force) (...
#
#                                                             1995  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        1.264083e+01
# ALB_Exports of goods and services, PPP (constan...  1.839533e+09
# ALB_Exports of goods and services, PPP (constan...  5.770571e+02
# ALB_Exports of goods and services, PPP (constan...  1.376729e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  4.565026e+03
# ALB_GDP, PPP (constant 2017 international $)        1.455232e+10
# ALB_Gross capital formation (% of GDP)              2.127851e+01
# ALB_Labor force, total                              1.336162e+06
# ALB_Population, total                               3.187784e+06
# ALB_Unemployment, total (% of total labor force...  1.652200e+01
#
#                                                             1996  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        1.162044e+01
# ALB_Exports of goods and services, PPP (constan...  1.844928e+09
# ALB_Exports of goods and services, PPP (constan...  5.823575e+02
# ALB_Exports of goods and services, PPP (constan...  1.386004e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  5.011493e+03
# ALB_GDP, PPP (constant 2017 international $)        1.587658e+10
# ALB_Gross capital formation (% of GDP)              1.806378e+01
# ALB_Labor force, total                              1.331113e+06
# ALB_Population, total                               3.168033e+06
# ALB_Unemployment, total (% of total labor force...  1.655000e+01
#
#                                                             1997  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        1.019726e+01
# ALB_Exports of goods and services, PPP (constan...  1.442184e+09
# ALB_Exports of goods and services, PPP (constan...  4.580862e+02
# ALB_Exports of goods and services, PPP (constan...  1.071489e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  4.492247e+03
# ALB_GDP, PPP (constant 2017 international $)        1.414286e+10
# ALB_Gross capital formation (% of GDP)              1.665950e+01
# ALB_Labor force, total                              1.345962e+06
# ALB_Population, total                               3.148281e+06
# ALB_Unemployment, total (% of total labor force...  1.652500e+01
#
#                                                             1998  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        1.146711e+01
# ALB_Exports of goods and services, PPP (constan...  1.764982e+09
# ALB_Exports of goods and services, PPP (constan...  5.641568e+02
# ALB_Exports of goods and services, PPP (constan...  1.316877e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  4.919781e+03
# ALB_GDP, PPP (constant 2017 international $)        1.539168e+10
# ALB_Gross capital formation (% of GDP)              1.974258e+01
# ALB_Labor force, total                              1.340278e+06
# ALB_Population, total                               3.128530e+06
# ALB_Unemployment, total (% of total labor force...  1.651600e+01
#
#                                                             1999  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        1.684177e+01
# ALB_Exports of goods and services, PPP (constan...  2.926367e+09
# ALB_Exports of goods and services, PPP (constan...  9.413239e+02
# ALB_Exports of goods and services, PPP (constan...  2.198864e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  5.589224e+03
# ALB_GDP, PPP (constant 2017 international $)        1.737566e+10
# ALB_Gross capital formation (% of GDP)              1.973471e+01
# ALB_Labor force, total                              1.330854e+06
# ALB_Population, total                               3.108778e+06
# ALB_Unemployment, total (% of total labor force...  1.661100e+01
#
#                                                             2000  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.011536e+01
# ALB_Exports of goods and services, PPP (constan...  3.738092e+09
# ALB_Exports of goods and services, PPP (constan...  1.210120e+03
# ALB_Exports of goods and services, PPP (constan...  2.818103e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  6.015897e+03
# ALB_GDP, PPP (constant 2017 international $)        1.858327e+10
# ALB_Gross capital formation (% of GDP)              3.079626e+01
# ALB_Labor force, total                              1.326457e+06
# ALB_Population, total                               3.089027e+06
# ALB_Unemployment, total (% of total labor force...  1.657300e+01
#
#                                                             2001  ...  \
# Pays_indic                                                        ...
# ALB_Exports of goods and services (% of GDP)        2.133344e+01  ...
# ALB_Exports of goods and services, PPP (constan...  4.293106e+09  ...
# ALB_Exports of goods and services, PPP (constan...  1.402896e+03  ...
# ALB_Exports of goods and services, PPP (constan...  3.267930e+03  ...
# ALB_GDP per capita, PPP (constant 2017 internat...  6.576045e+03  ...
# ALB_GDP, PPP (constant 2017 international $)        2.012384e+10  ...
# ALB_Gross capital formation (% of GDP)              3.498868e+01  ...
# ALB_Labor force, total                              1.313708e+06  ...
# ALB_Population, total                               3.060173e+06  ...
# ALB_Unemployment, total (% of total labor force...  1.656700e+01  ...
#
#                                                             2010  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.797945e+01
# ALB_Exports of goods and services, PPP (constan...  8.943849e+09
# ALB_Exports of goods and services, PPP (constan...  3.070300e+03
# ALB_Exports of goods and services, PPP (constan...  7.295711e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.097341e+04
# ALB_GDP, PPP (constant 2017 international $)        3.196578e+10
# ALB_Gross capital formation (% of GDP)              3.030866e+01
# ALB_Labor force, total                              1.225905e+06
# ALB_Population, total                               2.913021e+06
# ALB_Unemployment, total (% of total labor force...  1.408600e+01
#
#                                                             2011  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.924150e+01
# ALB_Exports of goods and services, PPP (constan...  9.585192e+09
# ALB_Exports of goods and services, PPP (constan...  3.299328e+03
# ALB_Exports of goods and services, PPP (constan...  7.636465e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.128303e+04
# ALB_GDP, PPP (constant 2017 international $)        3.277941e+10
# ALB_Gross capital formation (% of GDP)              3.141361e+01
# ALB_Labor force, total                              1.255187e+06
# ALB_Population, total                               2.905195e+06
# ALB_Unemployment, total (% of total labor force...  1.348100e+01
#
#                                                             2012  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.893749e+01
# ALB_Exports of goods and services, PPP (constan...  9.619998e+09
# ALB_Exports of goods and services, PPP (constan...  3.316782e+03
# ALB_Exports of goods and services, PPP (constan...  7.478093e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.146189e+04
# ALB_GDP, PPP (constant 2017 international $)        3.324407e+10
# ALB_Gross capital formation (% of GDP)              2.832855e+01
# ALB_Labor force, total                              1.286424e+06
# ALB_Population, total                               2.900401e+06
# ALB_Unemployment, total (% of total labor force...  1.337600e+01
#
#                                                             2013  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.891635e+01
# ALB_Exports of goods and services, PPP (constan...  9.709293e+09
# ALB_Exports of goods and services, PPP (constan...  3.353708e+03
# ALB_Exports of goods and services, PPP (constan...  7.999800e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.159796e+04
# ALB_GDP, PPP (constant 2017 international $)        3.357717e+10
# ALB_Gross capital formation (% of GDP)              2.805254e+01
# ALB_Labor force, total                              1.213692e+06
# ALB_Population, total                               2.895092e+06
# ALB_Unemployment, total (% of total labor force...  1.586600e+01
#
#                                                             2014  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.821298e+01
# ALB_Exports of goods and services, PPP (constan...  9.641219e+09
# ALB_Exports of goods and services, PPP (constan...  3.337097e+03
# ALB_Exports of goods and services, PPP (constan...  7.801608e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.182823e+04
# ALB_GDP, PPP (constant 2017 international $)        3.417299e+10
# ALB_Gross capital formation (% of GDP)              2.567468e+01
# ALB_Labor force, total                              1.235799e+06
# ALB_Population, total                               2.889104e+06
# ALB_Unemployment, total (% of total labor force...  1.749000e+01
#
#                                                             2015  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.726739e+01
# ALB_Exports of goods and services, PPP (constan...  9.524830e+09
# ALB_Exports of goods and services, PPP (constan...  3.306425e+03
# ALB_Exports of goods and services, PPP (constan...  7.386097e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.212593e+04
# ALB_GDP, PPP (constant 2017 international $)        3.493121e+10
# ALB_Gross capital formation (% of GDP)              2.581903e+01
# ALB_Labor force, total                              1.289562e+06
# ALB_Population, total                               2.880703e+06
# ALB_Unemployment, total (% of total labor force...  1.708000e+01
#
#                                                             2016  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        2.897786e+01
# ALB_Exports of goods and services, PPP (constan...  1.045785e+10
# ALB_Exports of goods and services, PPP (constan...  3.636122e+03
# ALB_Exports of goods and services, PPP (constan...  8.026991e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.254793e+04
# ALB_GDP, PPP (constant 2017 international $)        3.608911e+10
# ALB_Gross capital formation (% of GDP)              2.522386e+01
# ALB_Labor force, total                              1.302836e+06
# ALB_Population, total                               2.876101e+06
# ALB_Unemployment, total (% of total labor force...  1.522000e+01
#
#                                                             2017  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        3.156982e+01
# ALB_Exports of goods and services, PPP (constan...  1.182646e+10
# ALB_Exports of goods and services, PPP (constan...  4.115761e+03
# ALB_Exports of goods and services, PPP (constan...  8.980742e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.303701e+04
# ALB_GDP, PPP (constant 2017 international $)        3.746129e+10
# ALB_Gross capital formation (% of GDP)              2.505253e+01
# ALB_Labor force, total                              1.316869e+06
# ALB_Population, total                               2.873457e+06
# ALB_Unemployment, total (% of total labor force...  1.375000e+01
#
#                                                             2018  \
# Pays_indic
# ALB_Exports of goods and services (% of GDP)        3.159157e+01
# ALB_Exports of goods and services, PPP (constan...  1.231643e+10
# ALB_Exports of goods and services, PPP (constan...  4.296866e+03
# ALB_Exports of goods and services, PPP (constan...  9.344634e+03
# ALB_GDP per capita, PPP (constant 2017 internat...  1.360130e+04
# ALB_GDP, PPP (constant 2017 international $)        3.898645e+10
# ALB_Gross capital formation (% of GDP)              2.410103e+01
# ALB_Labor force, total                              1.318022e+06
# ALB_Population, total                               2.866376e+06
# ALB_Unemployment, total (% of total labor force...  1.234000e+01
#
#                                                       Simple Indicator
# Pays_indic
# ALB_Exports of goods and services (% of GDP)              exports_rate
# ALB_Exports of goods and services, PPP (constan...             exports
# ALB_Exports of goods and services, PPP (constan...         exports_hab
# ALB_Exports of goods and services, PPP (constan...  exports_labor_unit
# ALB_GDP per capita, PPP (constant 2017 internat...             gdb_hab
# ALB_GDP, PPP (constant 2017 international $)                       gdp
# ALB_Gross capital formation (% of GDP)                            FBCF
# ALB_Labor force, total                                     labor_force
# ALB_Population, total                                              pop
# ALB_Unemployment, total (% of total labor force...   unemployment rate
#
# [10 rows x 28 columns]

# %% [markdown]
# On affiche le nombre de pays, et on vérifie qu'on a bien toujours la France, et on affiche la taille du df.

# %%
print('On a conservé ', len(dic_code.keys()), ' pays')
print('La taille du df est de ', df1.shape)
df1.loc[rech_ligne_pays('France', df1)]
# Out:
# On a conservé  138  pays
# La taille du df est de  (1380, 28)
#                                                    Country Name Country Code  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)             France          FRA
# FRA_Exports of goods and services, PPP (constan...       France          FRA
# FRA_Exports of goods and services, PPP (constan...       France          FRA
# FRA_Exports of goods and services, PPP (constan...       France          FRA
# FRA_GDP per capita, PPP (constant 2017 internat...       France          FRA
# FRA_GDP, PPP (constant 2017 international $)             France          FRA
# FRA_Gross capital formation (% of GDP)                   France          FRA
# FRA_Labor force, total                                   France          FRA
# FRA_Population, total                                    France          FRA
# FRA_Unemployment, total (% of total labor force...       France          FRA
#
#                                                                                        Indicator Name  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)                 Exports of goods and services (% of GDP)
# FRA_Exports of goods and services, PPP (constan...  Exports of goods and services, PPP (constant 2...
# FRA_Exports of goods and services, PPP (constan...  _Exports of goods and services, PPP (constant ...
# FRA_Exports of goods and services, PPP (constan...  _Exports of goods and services, PPP (constant ...
# FRA_GDP per capita, PPP (constant 2017 internat...  GDP per capita, PPP (constant 2017 internation...
# FRA_GDP, PPP (constant 2017 international $)                 GDP, PPP (constant 2017 international $)
# FRA_Gross capital formation (% of GDP)                             Gross capital formation (% of GDP)
# FRA_Labor force, total                                                             Labor force, total
# FRA_Population, total                                                               Population, total
# FRA_Unemployment, total (% of total labor force...  Unemployment, total (% of total labor force) (...
#
#                                                             1995  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.262293e+01
# FRA_Exports of goods and services, PPP (constan...  4.761169e+11
# FRA_Exports of goods and services, PPP (constan...  7.996334e+03
# FRA_Exports of goods and services, PPP (constan...  1.804015e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  3.534615e+04
# FRA_GDP, PPP (constant 2017 international $)        2.104577e+12
# FRA_Gross capital formation (% of GDP)              2.051314e+01
# FRA_Labor force, total                              2.639207e+07
# FRA_Population, total                               5.954190e+07
# FRA_Unemployment, total (% of total labor force...  1.183600e+01
#
#                                                             1996  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.305556e+01
# FRA_Exports of goods and services, PPP (constan...  4.920783e+11
# FRA_Exports of goods and services, PPP (constan...  8.235192e+03
# FRA_Exports of goods and services, PPP (constan...  1.841749e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  3.571889e+04
# FRA_GDP, PPP (constant 2017 international $)        2.134315e+12
# FRA_Gross capital formation (% of GDP)              1.962227e+01
# FRA_Labor force, total                              2.671799e+07
# FRA_Population, total                               5.975310e+07
# FRA_Unemployment, total (% of total labor force...  1.236700e+01
#
#                                                             1997  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.552320e+01
# FRA_Exports of goods and services, PPP (constan...  5.574721e+11
# FRA_Exports of goods and services, PPP (constan...  9.296648e+03
# FRA_Exports of goods and services, PPP (constan...  2.089074e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  3.642431e+04
# FRA_GDP, PPP (constant 2017 international $)        2.184178e+12
# FRA_Gross capital formation (% of GDP)              1.945200e+01
# FRA_Labor force, total                              2.668512e+07
# FRA_Population, total                               5.996485e+07
# FRA_Unemployment, total (% of total labor force...  1.256600e+01
#
#                                                             1998  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.612649e+01
# FRA_Exports of goods and services, PPP (constan...  5.911279e+11
# FRA_Exports of goods and services, PPP (constan...  9.821637e+03
# FRA_Exports of goods and services, PPP (constan...  2.201202e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  3.759264e+04
# FRA_GDP, PPP (constant 2017 international $)        2.262561e+12
# FRA_Gross capital formation (% of GDP)              2.068051e+01
# FRA_Labor force, total                              2.685478e+07
# FRA_Population, total                               6.018629e+07
# FRA_Unemployment, total (% of total labor force...  1.207500e+01
#
#                                                             1999  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.607654e+01
# FRA_Exports of goods and services, PPP (constan...  6.101836e+11
# FRA_Exports of goods and services, PPP (constan...  1.008623e+04
# FRA_Exports of goods and services, PPP (constan...  2.246687e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  3.867932e+04
# FRA_GDP, PPP (constant 2017 international $)        2.339972e+12
# FRA_Gross capital formation (% of GDP)              2.136390e+01
# FRA_Labor force, total                              2.715926e+07
# FRA_Population, total                               6.049672e+07
# FRA_Unemployment, total (% of total labor force...  1.198100e+01
#
#                                                             2000  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.859497e+01
# FRA_Exports of goods and services, PPP (constan...  6.953682e+11
# FRA_Exports of goods and services, PPP (constan...  1.141585e+04
# FRA_Exports of goods and services, PPP (constan...  2.541430e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  3.992259e+04
# FRA_GDP, PPP (constant 2017 international $)        2.431785e+12
# FRA_Gross capital formation (% of GDP)              2.248805e+01
# FRA_Labor force, total                              2.736130e+07
# FRA_Population, total                               6.091250e+07
# FRA_Unemployment, total (% of total labor force...  1.021700e+01
#
#                                                             2001  ...  \
# Pays_indic                                                        ...
# FRA_Exports of goods and services (% of GDP)        2.826590e+01  ...
# FRA_Exports of goods and services, PPP (constan...  7.010011e+11  ...
# FRA_Exports of goods and services, PPP (constan...  1.142488e+04  ...
# FRA_Exports of goods and services, PPP (constan...  2.555660e+04  ...
# FRA_GDP per capita, PPP (constant 2017 internat...  4.041930e+04  ...
# FRA_GDP, PPP (constant 2017 international $)        2.480024e+12  ...
# FRA_Gross capital formation (% of GDP)              2.216487e+01  ...
# FRA_Labor force, total                              2.742936e+07  ...
# FRA_Population, total                               6.135743e+07  ...
# FRA_Unemployment, total (% of total labor force...  8.610000e+00  ...
#
#                                                             2010  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.678830e+01
# FRA_Exports of goods and services, PPP (constan...  7.377191e+11
# FRA_Exports of goods and services, PPP (constan...  1.134472e+04
# FRA_Exports of goods and services, PPP (constan...  2.480327e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.234954e+04
# FRA_GDP, PPP (constant 2017 international $)        2.753885e+12
# FRA_Gross capital formation (% of GDP)              2.194629e+01
# FRA_Labor force, total                              2.974282e+07
# FRA_Population, total                               6.502751e+07
# FRA_Unemployment, total (% of total labor force...  8.871000e+00
#
#                                                             2011  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.842134e+01
# FRA_Exports of goods and services, PPP (constan...  7.998531e+11
# FRA_Exports of goods and services, PPP (constan...  1.224088e+04
# FRA_Exports of goods and services, PPP (constan...  2.689045e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.306933e+04
# FRA_GDP, PPP (constant 2017 international $)        2.814270e+12
# FRA_Gross capital formation (% of GDP)              2.322091e+01
# FRA_Labor force, total                              2.974488e+07
# FRA_Population, total                               6.534278e+07
# FRA_Unemployment, total (% of total labor force...  8.811000e+00
#
#                                                             2012  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.920303e+01
# FRA_Exports of goods and services, PPP (constan...  8.244255e+11
# FRA_Exports of goods and services, PPP (constan...  1.255601e+04
# FRA_Exports of goods and services, PPP (constan...  2.749478e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.299559e+04
# FRA_GDP, PPP (constant 2017 international $)        2.823082e+12
# FRA_Gross capital formation (% of GDP)              2.262663e+01
# FRA_Labor force, total                              2.998480e+07
# FRA_Population, total                               6.565981e+07
# FRA_Unemployment, total (% of total labor force...  9.400000e+00
#
#                                                             2013  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.936474e+01
# FRA_Exports of goods and services, PPP (constan...  8.337684e+11
# FRA_Exports of goods and services, PPP (constan...  1.263311e+04
# FRA_Exports of goods and services, PPP (constan...  2.767555e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.302135e+04
# FRA_GDP, PPP (constant 2017 international $)        2.839352e+12
# FRA_Gross capital formation (% of GDP)              2.228719e+01
# FRA_Labor force, total                              3.012654e+07
# FRA_Population, total                               6.599869e+07
# FRA_Unemployment, total (% of total labor force...  9.921000e+00
#
#                                                             2014  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        2.966668e+01
# FRA_Exports of goods and services, PPP (constan...  8.503960e+11
# FRA_Exports of goods and services, PPP (constan...  1.282415e+04
# FRA_Exports of goods and services, PPP (constan...  2.828234e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.322745e+04
# FRA_GDP, PPP (constant 2017 international $)        2.866502e+12
# FRA_Gross capital formation (% of GDP)              2.270983e+01
# FRA_Labor force, total                              3.006809e+07
# FRA_Population, total                               6.631207e+07
# FRA_Unemployment, total (% of total labor force...  1.029200e+01
#
#                                                             2015  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.059262e+01
# FRA_Exports of goods and services, PPP (constan...  8.866976e+11
# FRA_Exports of goods and services, PPP (constan...  1.332413e+04
# FRA_Exports of goods and services, PPP (constan...  2.942122e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.355340e+04
# FRA_GDP, PPP (constant 2017 international $)        2.898403e+12
# FRA_Gross capital formation (% of GDP)              2.271232e+01
# FRA_Labor force, total                              3.013803e+07
# FRA_Population, total                               6.654827e+07
# FRA_Unemployment, total (% of total labor force...  1.035900e+01
#
#                                                             2016  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.024754e+01
# FRA_Exports of goods and services, PPP (constan...  8.862996e+11
# FRA_Exports of goods and services, PPP (constan...  1.328305e+04
# FRA_Exports of goods and services, PPP (constan...  2.935038e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.391448e+04
# FRA_GDP, PPP (constant 2017 international $)        2.930154e+12
# FRA_Gross capital formation (% of GDP)              2.260939e+01
# FRA_Labor force, total                              3.019721e+07
# FRA_Population, total                               6.672410e+07
# FRA_Unemployment, total (% of total labor force...  1.005700e+01
#
#                                                             2017  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.094863e+01
# FRA_Exports of goods and services, PPP (constan...  9.276223e+11
# FRA_Exports of goods and services, PPP (constan...  1.387319e+04
# FRA_Exports of goods and services, PPP (constan...  3.067894e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.482651e+04
# FRA_GDP, PPP (constant 2017 international $)        2.997297e+12
# FRA_Gross capital formation (% of GDP)              2.343619e+01
# FRA_Labor force, total                              3.023646e+07
# FRA_Population, total                               6.686438e+07
# FRA_Unemployment, total (% of total labor force...  9.397000e+00
#
#                                                             2018  \
# Pays_indic
# FRA_Exports of goods and services (% of GDP)        3.171916e+01
# FRA_Exports of goods and services, PPP (constan...  9.677623e+11
# FRA_Exports of goods and services, PPP (constan...  1.445157e+04
# FRA_Exports of goods and services, PPP (constan...  3.184285e+04
# FRA_GDP per capita, PPP (constant 2017 internat...  4.556100e+04
# FRA_GDP, PPP (constant 2017 international $)        3.051034e+12
# FRA_Gross capital formation (% of GDP)              2.387174e+01
# FRA_Labor force, total                              3.039182e+07
# FRA_Population, total                               6.696591e+07
# FRA_Unemployment, total (% of total labor force...  9.059000e+00
#
#                                                       Simple Indicator
# Pays_indic
# FRA_Exports of goods and services (% of GDP)              exports_rate
# FRA_Exports of goods and services, PPP (constan...             exports
# FRA_Exports of goods and services, PPP (constan...         exports_hab
# FRA_Exports of goods and services, PPP (constan...  exports_labor_unit
# FRA_GDP per capita, PPP (constant 2017 internat...             gdb_hab
# FRA_GDP, PPP (constant 2017 international $)                       gdp
# FRA_Gross capital formation (% of GDP)                            FBCF
# FRA_Labor force, total                                     labor_force
# FRA_Population, total                                              pop
# FRA_Unemployment, total (% of total labor force...   unemployment rate
#
# [10 rows x 28 columns]

# %%
df1.to_csv('C:/Users/Titouan/Desktop/WB_data2.csv')
